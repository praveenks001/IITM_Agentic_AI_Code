# %% [markdown]
# # MP1 · Prompt Lab — Compare LLM Strategies on a Task
#
# **Starter template.** Fill in the TODOs. ~5-8 hours over 3 days.
#
# Read `learner/MP1_Brief.md` before starting if you haven't already.
#
# ---
#
# ## Setup

# %%
import asyncio
import json
import os
import time
from pathlib import Path
from pydantic import BaseModel, Field

import pandas as pd
from openai import AsyncOpenAI

# Make sure your OPENAI_API_KEY is set in the environment
assert os.environ.get('OPENAI_API_KEY'), 'Set OPENAI_API_KEY first'

client = AsyncOpenAI()

MODEL = 'gpt-4o-mini'
JUDGE_MODEL = 'gpt-4o'
TEMPERATURE = 0.0

# Cost rates ($ per token) — from W4 cost.py
RATES = {
    'gpt-4o-mini': {'in': 0.15 / 1_000_000, 'out': 0.60 / 1_000_000},
    'gpt-4o':      {'in': 2.50 / 1_000_000, 'out': 10.00 / 1_000_000},
}

print('Setup complete.')
# Out:
# Setup complete.

# %% [markdown]
# ## Step 1 — Load the data

# %%
DATA_DIR = Path('../data')   # adjust if your folder layout differs
print('DATA_DIR is:',DATA_DIR)

snippets = [json.loads(line) for line in (DATA_DIR / 'job_snippets.jsonl').read_text().splitlines() if line.strip()]
golden = {row['id']: row for row in (json.loads(line) for line in (DATA_DIR / 'golden_set.jsonl').read_text().splitlines() if line.strip())}

print(f'Loaded {len(snippets)} snippets, {len(golden)} golden entries.')
print('Sample snippet:', snippets[0])
print('golden set loaded is:',golden)
# Out:
# DATA_DIR is: ../data
# Loaded 10 snippets, 10 golden entries.
# Sample snippet: {'id': 'j01', 'snippet': 'Acme Corp is hiring a Senior Software Engineer to join our platform team. The ideal candidate has 5+ years of backend development experience and strong skills in Python and distributed systems.'}
# golden set loaded is: {'j01': {'id': 'j01', 'company': 'Acme Corp', 'role': 'Senior Software Engineer', 'years_experience_required': 5, 'notes': 'clean — clear company + role + years'}, 'j02': {'id': 'j02', 'company': 'Northwind Ltd', 'role': 'Data Analyst', 'years_experience_required': 2, 'notes': 'clean — preferred used but still a stated minimum'}, 'j03': {'id': 'j03', 'company': 'Globex International', 'role': 'Product Manager - Growth', 'years_experience_required': 4, 'notes': "clean — 'at least 4 years'"}, 'j04': {'id': 'j04', 'company': 'Initech', 'role': 'Lead DevOps Engineer', 'years_experience_required': 6, 'notes': "slightly fuzzy — 'around 6 years' — accept 6"}, 'j05': {'id': 'j05', 'company': 'Hooli', 'role': 'Junior Frontend Developer', 'years_experience_required': 0, 'notes': 'edge — fresh grads OK = 0 years'}, 'j06': {'id': 'j06', 'company': 'Pied Piper Inc.', 'role': 'Senior ML Engineer', 'years_experience_required': 7, 'notes': "fuzzy — '7+ years' typically taken as 7; exceptional candidates clause is colour text"}, 'j07': {'id': 'j07', 'company': 'Soylent Industries', 'role': 'Engineering Manager', 'years_experience_required': 3, 'notes': "spelled-out number — 'about three years' → 3"}, 'j08': {'id': 'j08', 'company': 'Wonka Confectionery Ltd', 'role': 'Senior UX Researcher', 'years_experience_required': 5, 'notes': "clean — 'five years' → 5"}, 'j09': {'id': 'j09', 'company': 'Stark Industries', 'role': 'Cybersecurity Analyst', 'years_experience_required': 3, 'notes': "range 3-5 — take the minimum, 3. Accept 3 or 'between 3 and 5'."}, 'j10': {'id': 'j10', 'company': 'Cyberdyne Systems', 'role': 'AI/ML Research Scientist', 'years_experience_required': None, 'notes': 'edge — no years stated. Correct answer: null. Penalise if model fabricates a number.'}}

# %% [markdown]
# ## Step 2 — Write the four prompt strategies
#
# Each strategy is a function that takes a snippet text and returns the messages list to send to the LLM.
#
# Implement all four. Keep each one focused — the point is to *see* the difference between strategies, not to over-engineer any one.
#
# **TODO:** fill in the four `prompt_*` functions below.

# %%
def prompt_zero_shot(snippet_text: str) -> list[dict]:
    """Strategy 1 — zero-shot. Just ask, no examples, no persona."""

    return [
        {
            "role": "user",
            "content": f"""
Extract the company name, job role, and number of years of experience
required from the following job description.

Return the response only in JSON with these fields:
company, role, years_experience_required.

Job description:{snippet_text}"""
        }
    ]







def prompt_few_shot(snippet_text: str) -> list[dict]:
    """Strategy 2 — few-shot. Include worked examples in the prompt."""

    return [
        {
            "role": "user",
            "content": f"""
Extract the hiring company name, job role, and number of years
of experience required from the job description.

Return the response ONLY in JSON with these fields:
company, role, years_experience_required.

Example:

Job description:
ABC is hiring an ML Engineer with 5 years of experience
in machine learning and Python.

Output:
{{
    "company": "ABC",
    "role": "ML Engineer",
    "years_experience_required": 5
}}

If no years of experience are mentioned, return null.

Now extract the information from the following job description:

{snippet_text}

Return ONLY the JSON response.
"""
        }
    ]







def prompt_structured(snippet_text: str) -> list[dict]:
    """Strategy 3 — structured / role-based.
    Use a system prompt with a persona and explicit JSON schema.
    """

    return [
        {
            "role": "system",
            "content": """
ROLE:
You are a job extraction expert and recruitment assistant.

TASK:
Extract the hiring company name, job role, and number of years
of experience required from the job description.

If the required information is not present in the context,
return null for the missing value.
Do not invent or hallucinate information.

EXAMPLE:

Job description:
ABC is hiring an ML Engineer with 5 years of experience
in machine learning and Python.

Output:
{
    "company": "ABC",
    "role": "ML Engineer",
    "years_experience_required": 5
}

FORMAT:
Return ONLY valid JSON using exactly these fields:

{
    "company": "string or null",
    "role": "string or null",
    "years_experience_required": "integer or null"
}
"""
        },
        {
            "role": "user",
            "content": f"""
Job description:

{snippet_text}
"""
        }
    ]








def prompt_cot(snippet_text: str) -> list[dict]:
    """Strategy 4 — chain-of-thought. Ask the model to reason before answering."""
    return [
        {
            "role": "system",
            "content": """
You are a careful job extraction expert and recruitment assistant.

TASK:
Analyze the job description step by step and identify:

1. The hiring company name
2. The job role
3. The required skillset
4. The minimum number of years of experience required

REASONING RULES:
- Carefully inspect the full job description before answering.
- Identify the company name only if it is explicitly stated.
- Identify the exact job role.
- Extract only the skillsets mentioned in the job description.
- Determine the minimum years of experience required.
- For "5+ years", return 5.
- For "at least 4 years", return 4.
- For "around 6 years", return 6.
- For "about three years", return 3.
- For a range such as "3-5 years", return 3.
- If fresh graduates are accepted, return 0.
- If years of experience are not mentioned, return null.
- If any other information is missing, return null.
- Do not guess or hallucinate information.

Think through the extraction carefully before producing the answer,
but return ONLY the final JSON result.

FORMAT:
Return only valid JSON with exactly these fields:

{
    "company": "string or null",
    "role": "string or null",
    "skillset": "string or null",
    "years_experience_required": "integer or null"
}
"""
        },
        {
            "role": "user",
            "content": f"""
Analyze the following job description carefully:

{snippet_text}

Return only the final JSON response.
"""
        }
    ]




STRATEGIES = {
    'zero_shot': prompt_zero_shot,
    'few_shot': prompt_few_shot,
    'structured': prompt_structured,
    'cot': prompt_cot,
}

# %% [markdown]
# ## Step 3 — Async batching
#
# Run all 10 snippets × 4 strategies = 40 calls in parallel.
#
# Capture for each call: strategy, snippet_id, raw response, parsed extraction, cost, latency.
#
# **TODO:** implement `run_one` (single call) and `run_all` (batch all 40).

# %%
import random

def parse_response(text: str) -> dict | None:
    """Try to parse a JSON object out of the model's response. Return None if it doesn't parse.
    
    Hint: models sometimes wrap JSON in ```json ... ``` fences. Strip them first.
    """
    # TODO: extract + parse the JSON, return a dict or None
    
    print("Executing parse_response ::",text)

    text = text.strip()

    if text.startswith("```json"):
        text = text[7:]

    if text.endswith("```"):
        text = text[:-3]

    text = text.strip()
    print("text before loading json",text)

    parsed = json.loads(text)
    print("Response parsed is::", parsed)

    if parsed is not None:
        print("Since parsed response is not null mapping the fields")
        company = parsed.get("company")
        role = parsed.get("role")
        years_experience_required = parsed.get(
            "years_experience_required"
        )

        print("Company:", company)
        print("Role:", role)
        print("Years:", years_experience_required)


    else:
        print("Parsed response is null")
        company = None
        role = None
        years_experience_required = None

    print("final parsed response is::",company,role,years_experience_required)
    return parsed


async def run_one(strategy_name: str, snippets: list[dict]) -> list[dict]:
    """Run one strategy against all job snippets asynchronously."""

    #Iterating one strategy (zero shot) against each snippets and use gather for batch processing
    activity = [
        run_each_snippet(strategy_name, snippet)
        for snippet in snippets
    ]

    results = await asyncio.gather(*activity)

    return results




async def run_all(snippets: list[dict]) -> list[dict]:
    """Run all 10 × 4 = 40 calls in parallel. Use asyncio.gather."""
    # TODO: build the task list, gather, return results
    activity = []

    #Iterating each strategy against each snippets and use gather for batch processing
    for strategy_name in STRATEGIES:
        for snippet in snippets:
            activity.append(run_each_snippet(strategy_name,snippet))

    results = await asyncio.gather(
        *activity,
        return_exceptions=True
    )

    return results





# from types import SimpleNamespace
async def run_each_snippet(strategy_name: str, snippet: dict) -> dict:
    """Run one strategy on one snippet. Return a dict with all the captured fields."""
    
    print("strategy name is:::", strategy_name)
    print("snippet id is::::", snippet["id"])
    print("snippet is::::", snippet["snippet"])

    prompt_func_name = STRATEGIES[strategy_name]
    prompt = prompt_func_name(snippet["snippet"])
    print("prompt fetched is::::", prompt)

    #start calculating latency
    start_time = time.perf_counter()
    #await asyncio.sleep(random.uniform(0.3, 1.5))


    resp = await client.chat.completions.create(
        model=MODEL,
       messages=prompt,
        temperature=0.0
    )
    elapsed_time = time.perf_counter() - start_time

    print(f"Latency: {elapsed_time:.4f} seconds")
    print("response from LLM is:::", resp)

    raw_response = resp.choices[0].message.content
    usage = resp.usage
    print("response usage from LLM is:::", usage)

    # resp = ""
    # raw_response = {
    # "id": "chatcmpl-EEGWRe7DU51LvNoTIfHOAyUTECjy3",

    # "content": """```json
    # {
    #   "company": "Acme Corp",
    #   "role": "Senior Software Engineer",
    #   "years_experience_required": 5
    # }```""",

    # "model": "gpt-4o-mini-2024-07-18",

    # "usage": {
    #     "completion_tokens": 34,
    #     "prompt_tokens": 88,
    #     "total_tokens": 122
    # }
    # }
    # print("response from LLM is:::", raw_response)
    # usage=SimpleNamespace(
    #         prompt_tokens=88,
    #         completion_tokens=34,
    #         total_tokens=122
    #     )



    cost = compute_cost_usd(
                MODEL,
                usage.prompt_tokens if usage else 0,
                usage.completion_tokens if usage else 0,
        )
    print("cost incurred is:::", cost)

    # Parse JSON returned by LLM
    #parsedresponse = parse_response(raw_response["content"])
    parsedresponse = parse_response(raw_response)
    print("parsedresponse is:::",parsedresponse)
    
    # Return captured result
    return {
        "id": snippet["id"],
        "strategy": strategy_name,
        "company": parsedresponse["company"],
        "role": parsedresponse["role"],
        "years_experience_required":  parsedresponse["years_experience_required"],
        "raw_response": raw_response,
        "parsed_response": parsedresponse,
        "prompt_tokens": usage.prompt_tokens if usage else 0,
        "completion_tokens": usage.completion_tokens if usage else 0,
        "total_tokens": usage.total_tokens if usage else 0,
        "cost_usd": cost,
        "latency_seconds": elapsed_time
    }


def compute_cost_usd(model: str, prompt_tokens: int, completion_tokens: int) -> float:
    """Convert a usage tuple into USD.

    Returns 0.0 for unknown models rather than raising — a missing rate
    shouldn't break a batch run; it just means we can't price that call.
    """
    print("prompt_tokens::::",prompt_tokens, "completion_tokens::::",completion_tokens, "model::::",model)

    rates = RATES.get(model)

    if rates is None:
        return 0.0
    in_rate = rates['in']
    out_rate = rates['out']
    final_cost = (prompt_tokens * in_rate + completion_tokens * out_rate)
    print(f"${final_cost:.8f}")
    return final_cost #return (f"${final_cost:.8f}")
    #return (prompt_tokens * in_rate + completion_tokens * out_rate) / 1_000_000.0

# %%
# Run it

# results = await run_one("zero_shot", snippets)
# print("final result is:::",results)

results = await run_all(snippets)
print(f'Got {len(results)} results.')
results[0]

# Write results to output file
OUTPUT_FILE = DATA_DIR / "output4.txt"

with open(OUTPUT_FILE, "w", encoding="utf-8") as f:
    for result in results:
        f.write(str(result))
        f.write("\n")

print("Results written to:", OUTPUT_FILE)
# Out:
# strategy name is::: zero_shot
# snippet id is:::: j01
# snippet is:::: Acme Corp is hiring a Senior Software Engineer to join our platform team. The ideal candidate has 5+ years of backend development experience and strong skills in Python and distributed systems.
# prompt fetched is:::: [{'role': 'user', 'content': '\nExtract the company name, job role, and number of years of experience\nrequired from the following job description.\n\nReturn the response only in JSON with these fields:\ncompany, role, years_experience_required.\n\nJob description:Acme Corp is hiring a Senior Software Engineer to join our platform team. The ideal candidate has 5+ years of backend development experience and strong skills in Python and distributed systems.'}]
# strategy name is::: zero_shot
# snippet id is:::: j02
# snippet is:::: We're looking for a Data Analyst at Northwind Ltd. Reporting to the Head of Analytics, you'll work with SQL, dashboards, and stakeholder requests. 2 years minimum experience preferred.
# prompt fetched is:::: [{'role': 'user', 'content': "\nExtract the company name, job role, and number of years of experience\nrequired from the following job description.\n\nReturn the response only in JSON with these fields:\ncompany, role, years_experience_required.\n\nJob description:We're looking for a Data Analyst at Northwind Ltd. Reporting to the Head of Analytics, you'll work with SQL, dashboards, and stakeholder requests. 2 years minimum experience preferred."}]
# strategy name is::: zero_shot
# snippet id is:::: j03
# snippet is:::: Globex International seeks a Product Manager - Growth. You'll own activation and onboarding metrics across our consumer apps. We're looking for someone with at least 4 years of product management experience in B2C contexts.
# prompt fetched is:::: [{'role': 'user', 'content': "\nExtract the company name, job role, and number of years of experience\nrequired from the following job description.\n\nReturn the response only in JSON with these fields:\ncompany, role, years_experience_required.\n\nJob description:Globex International seeks a Product Manager - Growth. You'll own activation and onboarding metrics across our consumer apps. We're looking for someone with at least 4 years of product management experience in B2C contexts."}]
# strategy name is::: zero_shot
# snippet id is:::: j04
# snippet is:::: Join Initech as a Lead DevOps Engineer. We need a builder, not a maintainer. Around 6 years of hands-on infrastructure work expected, ideally with AWS, Terraform, and modern CI/CD.
# prompt fetched is:::: [{'role': 'user', 'content': '\nExtract the company name, job role, and number of years of experience\nrequired from the following job description.\n\nReturn the response only in JSON with these fields:\ncompany, role, years_experience_required.\n\nJob description:Join Initech as a Lead DevOps Engineer. We need a builder, not a maintainer. Around 6 years of hands-on infrastructure work expected, ideally with AWS, Terraform, and modern CI/CD.'}]
# strategy name is::: zero_shot
# snippet id is:::: j05
# snippet is:::: Hooli is looking for a Junior Frontend Developer. Fresh grads welcome — no prior experience required. We care about curiosity and willingness to learn. JavaScript, React, and CSS fundamentals expected.
# prompt fetched is:::: [{'role': 'user', 'content': '\nExtract the company name, job role, and number of years of experience\nrequired from the following job description.\n\nReturn the response only in JSON with these fields:\ncompany, role, years_experience_required.\n\nJob description:Hooli is looking for a Junior Frontend Developer. Fresh grads welcome — no prior experience required. We care about curiosity and willingness to learn. JavaScript, React, and CSS fundamentals expected.'}]
# strategy name is::: zero_shot
# snippet id is:::: j06
# snippet is:::: Pied Piper Inc. has an opening for a Senior ML Engineer. Compression algorithms background a plus. We typically look for 7+ years in production ML and distributed systems, but exceptional candidates with less are welcome.
# prompt fetched is:::: [{'role': 'user', 'content': '\nExtract the company name, job role, and number of years of experience\nrequired from the following job description.\n\nReturn the response only in JSON with these fields:\ncompany, role, years_experience_required.\n\nJob description:Pied Piper Inc. has an opening for a Senior ML Engineer. Compression algorithms background a plus. We typically look for 7+ years in production ML and distributed systems, but exceptional candidates with less are welcome.'}]
# strategy name is::: zero_shot
# snippet id is:::: j07
# snippet is:::: We want a builder. Soylent Industries is growing fast. The role is Engineering Manager. About three years leading engineering teams, plus a solid IC background before that. Apply if you've shipped real products.
# prompt fetched is:::: [{'role': 'user', 'content': "\nExtract the company name, job role, and number of years of experience\nrequired from the following job description.\n\nReturn the response only in JSON with these fields:\ncompany, role, years_experience_required.\n\nJob description:We want a builder. Soylent Industries is growing fast. The role is Engineering Manager. About three years leading engineering teams, plus a solid IC background before that. Apply if you've shipped real products."}]
# strategy name is::: zero_shot
# snippet id is:::: j08
# snippet is:::: Senior UX Researcher at Wonka Confectionery Ltd. You'll design and run user studies for our digital storefront. Five years of UX research experience or equivalent portfolio required.
# prompt fetched is:::: [{'role': 'user', 'content': "\nExtract the company name, job role, and number of years of experience\nrequired from the following job description.\n\nReturn the response only in JSON with these fields:\ncompany, role, years_experience_required.\n\nJob description:Senior UX Researcher at Wonka Confectionery Ltd. You'll design and run user studies for our digital storefront. Five years of UX research experience or equivalent portfolio required."}]
# strategy name is::: zero_shot
# snippet id is:::: j09
# snippet is:::: Stark Industries: Cybersecurity Analyst (mid-level). Three to five years in a SOC environment or equivalent. Familiarity with SIEM tools, incident response runbooks, and basic threat modelling.
# prompt fetched is:::: [{'role': 'user', 'content': '\nExtract the company name, job role, and number of years of experience\nrequired from the following job description.\n\nReturn the response only in JSON with these fields:\ncompany, role, years_experience_required.\n\nJob description:Stark Industries: Cybersecurity Analyst (mid-level). Three to five years in a SOC environment or equivalent. Familiarity with SIEM tools, incident response runbooks, and basic threat modelling.'}]
# strategy name is::: zero_shot
# snippet id is:::: j10
# snippet is:::: Cyberdyne Systems is hiring. Role: AI/ML Research Scientist. PhD preferred but not required. Strong publication record in deep learning or reinforcement learning. We don't list a specific years requirement — we hire on demonstrated impact.
# prompt fetched is:::: [{'role': 'user', 'content': "\nExtract the company name, job role, and number of years of experience\nrequired from the following job description.\n\nReturn the response only in JSON with these fields:\ncompany, role, years_experience_required.\n\nJob description:Cyberdyne Systems is hiring. Role: AI/ML Research Scientist. PhD preferred but not required. Strong publication record in deep learning or reinforcement learning. We don't list a specific years requirement — we hire on demonstrated impact."}]
# strategy name is::: few_shot
# snippet id is:::: j01
# snippet is:::: Acme Corp is hiring a Senior Software Engineer to join our platform team. The ideal candidate has 5+ years of backend development experience and strong skills in Python and distributed systems.
# prompt fetched is:::: [{'role': 'user', 'content': '\nExtract the hiring company name, job role, and number of years\nof experience required from the job description.\n\nReturn the response ONLY in JSON with these fields:\ncompany, role, years_experience_required.\n\nExample:\n\nJob description:\nABC is hiring an ML Engineer with 5 years of experience\nin machine learning and Python.\n\nOutput:\n{\n    "company": "ABC",\n    "role": "ML Engineer",\n    "years_experience_required": 5\n}\n\nIf no years of experience are mentioned, return null.\n\nNow extract the information from the following job description:\n\nAcme Corp is hiring a Senior Software Engineer to join our platform team. The ideal candidate has 5+ years of backend development experience and strong skills in Python and distributed systems.\n\nReturn ONLY the JSON response.\n'}]
# strategy name is::: few_shot
# snippet id is:::: j02
# snippet is:::: We're looking for a Data Analyst at Northwind Ltd. Reporting to the Head of Analytics, you'll work with SQL, dashboards, and stakeholder requests. 2 years minimum experience preferred.
# prompt fetched is:::: [{'role': 'user', 'content': '\nExtract the hiring company name, job role, and number of years\nof experience required from the job description.\n\nReturn the response ONLY in JSON with these fields:\ncompany, role, years_experience_required.\n\nExample:\n\nJob description:\nABC is hiring an ML Engineer with 5 years of experience\nin machine learning and Python.\n\nOutput:\n{\n    "company": "ABC",\n    "role": "ML Engineer",\n    "years_experience_required": 5\n}\n\nIf no years of experience are mentioned, return null.\n\nNow extract the information from the following job description:\n\nWe\'re looking for a Data Analyst at Northwind Ltd. Reporting to the Head of Analytics, you\'ll work with SQL, dashboards, and stakeholder requests. 2 years minimum experience preferred.\n\nReturn ONLY the JSON response.\n'}]
# strategy name is::: few_shot
# snippet id is:::: j03
# snippet is:::: Globex International seeks a Product Manager - Growth. You'll own activation and onboarding metrics across our consumer apps. We're looking for someone with at least 4 years of product management experience in B2C contexts.
# prompt fetched is:::: [{'role': 'user', 'content': '\nExtract the hiring company name, job role, and number of years\nof experience required from the job description.\n\nReturn the response ONLY in JSON with these fields:\ncompany, role, years_experience_required.\n\nExample:\n\nJob description:\nABC is hiring an ML Engineer with 5 years of experience\nin machine learning and Python.\n\nOutput:\n{\n    "company": "ABC",\n    "role": "ML Engineer",\n    "years_experience_required": 5\n}\n\nIf no years of experience are mentioned, return null.\n\nNow extract the information from the following job description:\n\nGlobex International seeks a Product Manager - Growth. You\'ll own activation and onboarding metrics across our consumer apps. We\'re looking for someone with at least 4 years of product management experience in B2C contexts.\n\nReturn ONLY the JSON response.\n'}]
# strategy name is::: few_shot
# snippet id is:::: j04
# snippet is:::: Join Initech as a Lead DevOps Engineer. We need a builder, not a maintainer. Around 6 years of hands-on infrastructure work expected, ideally with AWS, Terraform, and modern CI/CD.
# prompt fetched is:::: [{'role': 'user', 'content': '\nExtract the hiring company name, job role, and number of years\nof experience required from the job description.\n\nReturn the response ONLY in JSON with these fields:\ncompany, role, years_experience_required.\n\nExample:\n\nJob description:\nABC is hiring an ML Engineer with 5 years of experience\nin machine learning and Python.\n\nOutput:\n{\n    "company": "ABC",\n    "role": "ML Engineer",\n    "years_experience_required": 5\n}\n\nIf no years of experience are mentioned, return null.\n\nNow extract the information from the following job description:\n\nJoin Initech as a Lead DevOps Engineer. We need a builder, not a maintainer. Around 6 years of hands-on infrastructure work expected, ideally with AWS, Terraform, and modern CI/CD.\n\nReturn ONLY the JSON response.\n'}]
# strategy name is::: few_shot
# snippet id is:::: j05
# snippet is:::: Hooli is looking for a Junior Frontend Developer. Fresh grads welcome — no prior experience required. We care about curiosity and willingness to learn. JavaScript, React, and CSS fundamentals expected.
# prompt fetched is:::: [{'role': 'user', 'content': '\nExtract the hiring company name, job role, and number of years\nof experience required from the job description.\n\nReturn the response ONLY in JSON with these fields:\ncompany, role, years_experience_required.\n\nExample:\n\nJob description:\nABC is hiring an ML Engineer with 5 years of experience\nin machine learning and Python.\n\nOutput:\n{\n    "company": "ABC",\n    "role": "ML Engineer",\n    "years_experience_required": 5\n}\n\nIf no years of experience are mentioned, return null.\n\nNow extract the information from the following job description:\n\nHooli is looking for a Junior Frontend Developer. Fresh grads welcome — no prior experience required. We care about curiosity and willingness to learn. JavaScript, React, and CSS fundamentals expected.\n\nReturn ONLY the JSON response.\n'}]
# strategy name is::: few_shot
# snippet id is:::: j06
# snippet is:::: Pied Piper Inc. has an opening for a Senior ML Engineer. Compression algorithms background a plus. We typically look for 7+ years in production ML and distributed systems, but exceptional candidates with less are welcome.
# prompt fetched is:::: [{'role': 'user', 'content': '\nExtract the hiring company name, job role, and number of years\nof experience required from the job description.\n\nReturn the response ONLY in JSON with these fields:\ncompany, role, years_experience_required.\n\nExample:\n\nJob description:\nABC is hiring an ML Engineer with 5 years of experience\nin machine learning and Python.\n\nOutput:\n{\n    "company": "ABC",\n    "role": "ML Engineer",\n    "years_experience_required": 5\n}\n\nIf no years of experience are mentioned, return null.\n\nNow extract the information from the following job description:\n\nPied Piper Inc. has an opening for a Senior ML Engineer. Compression algorithms background a plus. We typically look for 7+ years in production ML and distributed systems, but exceptional candidates with less are welcome.\n\nReturn ONLY the JSON response.\n'}]
# strategy name is::: few_shot
# snippet id is:::: j07
# snippet is:::: We want a builder. Soylent Industries is growing fast. The role is Engineering Manager. About three years leading engineering teams, plus a solid IC background before that. Apply if you've shipped real products.
# prompt fetched is:::: [{'role': 'user', 'content': '\nExtract the hiring company name, job role, and number of years\nof experience required from the job description.\n\nReturn the response ONLY in JSON with these fields:\ncompany, role, years_experience_required.\n\nExample:\n\nJob description:\nABC is hiring an ML Engineer with 5 years of experience\nin machine learning and Python.\n\nOutput:\n{\n    "company": "ABC",\n    "role": "ML Engineer",\n    "years_experience_required": 5\n}\n\nIf no years of experience are mentioned, return null.\n\nNow extract the information from the following job description:\n\nWe want a builder. Soylent Industries is growing fast. The role is Engineering Manager. About three years leading engineering teams, plus a solid IC background before that. Apply if you\'ve shipped real products.\n\nReturn ONLY the JSON response.\n'}]
# strategy name is::: few_shot
# snippet id is:::: j08
# snippet is:::: Senior UX Researcher at Wonka Confectionery Ltd. You'll design and run user studies for our digital storefront. Five years of UX research experience or equivalent portfolio required.
# prompt fetched is:::: [{'role': 'user', 'content': '\nExtract the hiring company name, job role, and number of years\nof experience required from the job description.\n\nReturn the response ONLY in JSON with these fields:\ncompany, role, years_experience_required.\n\nExample:\n\nJob description:\nABC is hiring an ML Engineer with 5 years of experience\nin machine learning and Python.\n\nOutput:\n{\n    "company": "ABC",\n    "role": "ML Engineer",\n    "years_experience_required": 5\n}\n\nIf no years of experience are mentioned, return null.\n\nNow extract the information from the following job description:\n\nSenior UX Researcher at Wonka Confectionery Ltd. You\'ll design and run user studies for our digital storefront. Five years of UX research experience or equivalent portfolio required.\n\nReturn ONLY the JSON response.\n'}]
# strategy name is::: few_shot
# snippet id is:::: j09
# snippet is:::: Stark Industries: Cybersecurity Analyst (mid-level). Three to five years in a SOC environment or equivalent. Familiarity with SIEM tools, incident response runbooks, and basic threat modelling.
# prompt fetched is:::: [{'role': 'user', 'content': '\nExtract the hiring company name, job role, and number of years\nof experience required from the job description.\n\nReturn the response ONLY in JSON with these fields:\ncompany, role, years_experience_required.\n\nExample:\n\nJob description:\nABC is hiring an ML Engineer with 5 years of experience\nin machine learning and Python.\n\nOutput:\n{\n    "company": "ABC",\n    "role": "ML Engineer",\n    "years_experience_required": 5\n}\n\nIf no years of experience are mentioned, return null.\n\nNow extract the information from the following job description:\n\nStark Industries: Cybersecurity Analyst (mid-level). Three to five years in a SOC environment or equivalent. Familiarity with SIEM tools, incident response runbooks, and basic threat modelling.\n\nReturn ONLY the JSON response.\n'}]
# strategy name is::: few_shot
# snippet id is:::: j10
# snippet is:::: Cyberdyne Systems is hiring. Role: AI/ML Research Scientist. PhD preferred but not required. Strong publication record in deep learning or reinforcement learning. We don't list a specific years requirement — we hire on demonstrated impact.
# prompt fetched is:::: [{'role': 'user', 'content': '\nExtract the hiring company name, job role, and number of years\nof experience required from the job description.\n\nReturn the response ONLY in JSON with these fields:\ncompany, role, years_experience_required.\n\nExample:\n\nJob description:\nABC is hiring an ML Engineer with 5 years of experience\nin machine learning and Python.\n\nOutput:\n{\n    "company": "ABC",\n    "role": "ML Engineer",\n    "years_experience_required": 5\n}\n\nIf no years of experience are mentioned, return null.\n\nNow extract the information from the following job description:\n\nCyberdyne Systems is hiring. Role: AI/ML Research Scientist. PhD preferred but not required. Strong publication record in deep learning or reinforcement learning. We don\'t list a specific years requirement — we hire on demonstrated impact.\n\nReturn ONLY the JSON response.\n'}]
# strategy name is::: structured
# snippet id is:::: j01
# snippet is:::: Acme Corp is hiring a Senior Software Engineer to join our platform team. The ideal candidate has 5+ years of backend development experience and strong skills in Python and distributed systems.
# prompt fetched is:::: [{'role': 'system', 'content': '\nROLE:\nYou are a job extraction expert and recruitment assistant.\n\nTASK:\nExtract the hiring company name, job role, and number of years\nof experience required from the job description.\n\nIf the required information is not present in the context,\nreturn null for the missing value.\nDo not invent or hallucinate information.\n\nEXAMPLE:\n\nJob description:\nABC is hiring an ML Engineer with 5 years of experience\nin machine learning and Python.\n\nOutput:\n{\n    "company": "ABC",\n    "role": "ML Engineer",\n    "years_experience_required": 5\n}\n\nFORMAT:\nReturn ONLY valid JSON using exactly these fields:\n\n{\n    "company": "string or null",\n    "role": "string or null",\n    "years_experience_required": "integer or null"\n}\n'}, {'role': 'user', 'content': '\nJob description:\n\nAcme Corp is hiring a Senior Software Engineer to join our platform team. The ideal candidate has 5+ years of backend development experience and strong skills in Python and distributed systems.\n'}]
# strategy name is::: structured
# snippet id is:::: j02
# snippet is:::: We're looking for a Data Analyst at Northwind Ltd. Reporting to the Head of Analytics, you'll work with SQL, dashboards, and stakeholder requests. 2 years minimum experience preferred.
# prompt fetched is:::: [{'role': 'system', 'content': '\nROLE:\nYou are a job extraction expert and recruitment assistant.\n\nTASK:\nExtract the hiring company name, job role, and number of years\nof experience required from the job description.\n\nIf the required information is not present in the context,\nreturn null for the missing value.\nDo not invent or hallucinate information.\n\nEXAMPLE:\n\nJob description:\nABC is hiring an ML Engineer with 5 years of experience\nin machine learning and Python.\n\nOutput:\n{\n    "company": "ABC",\n    "role": "ML Engineer",\n    "years_experience_required": 5\n}\n\nFORMAT:\nReturn ONLY valid JSON using exactly these fields:\n\n{\n    "company": "string or null",\n    "role": "string or null",\n    "years_experience_required": "integer or null"\n}\n'}, {'role': 'user', 'content': "\nJob description:\n\nWe're looking for a Data Analyst at Northwind Ltd. Reporting to the Head of Analytics, you'll work with SQL, dashboards, and stakeholder requests. 2 years minimum experience preferred.\n"}]
# strategy name is::: structured
# snippet id is:::: j03
# snippet is:::: Globex International seeks a Product Manager - Growth. You'll own activation and onboarding metrics across our consumer apps. We're looking for someone with at least 4 years of product management experience in B2C contexts.
# prompt fetched is:::: [{'role': 'system', 'content': '\nROLE:\nYou are a job extraction expert and recruitment assistant.\n\nTASK:\nExtract the hiring company name, job role, and number of years\nof experience required from the job description.\n\nIf the required information is not present in the context,\nreturn null for the missing value.\nDo not invent or hallucinate information.\n\nEXAMPLE:\n\nJob description:\nABC is hiring an ML Engineer with 5 years of experience\nin machine learning and Python.\n\nOutput:\n{\n    "company": "ABC",\n    "role": "ML Engineer",\n    "years_experience_required": 5\n}\n\nFORMAT:\nReturn ONLY valid JSON using exactly these fields:\n\n{\n    "company": "string or null",\n    "role": "string or null",\n    "years_experience_required": "integer or null"\n}\n'}, {'role': 'user', 'content': "\nJob description:\n\nGlobex International seeks a Product Manager - Growth. You'll own activation and onboarding metrics across our consumer apps. We're looking for someone with at least 4 years of product management experience in B2C contexts.\n"}]
# strategy name is::: structured
# snippet id is:::: j04
# snippet is:::: Join Initech as a Lead DevOps Engineer. We need a builder, not a maintainer. Around 6 years of hands-on infrastructure work expected, ideally with AWS, Terraform, and modern CI/CD.
# prompt fetched is:::: [{'role': 'system', 'content': '\nROLE:\nYou are a job extraction expert and recruitment assistant.\n\nTASK:\nExtract the hiring company name, job role, and number of years\nof experience required from the job description.\n\nIf the required information is not present in the context,\nreturn null for the missing value.\nDo not invent or hallucinate information.\n\nEXAMPLE:\n\nJob description:\nABC is hiring an ML Engineer with 5 years of experience\nin machine learning and Python.\n\nOutput:\n{\n    "company": "ABC",\n    "role": "ML Engineer",\n    "years_experience_required": 5\n}\n\nFORMAT:\nReturn ONLY valid JSON using exactly these fields:\n\n{\n    "company": "string or null",\n    "role": "string or null",\n    "years_experience_required": "integer or null"\n}\n'}, {'role': 'user', 'content': '\nJob description:\n\nJoin Initech as a Lead DevOps Engineer. We need a builder, not a maintainer. Around 6 years of hands-on infrastructure work expected, ideally with AWS, Terraform, and modern CI/CD.\n'}]
# strategy name is::: structured
# snippet id is:::: j05
# snippet is:::: Hooli is looking for a Junior Frontend Developer. Fresh grads welcome — no prior experience required. We care about curiosity and willingness to learn. JavaScript, React, and CSS fundamentals expected.
# prompt fetched is:::: [{'role': 'system', 'content': '\nROLE:\nYou are a job extraction expert and recruitment assistant.\n\nTASK:\nExtract the hiring company name, job role, and number of years\nof experience required from the job description.\n\nIf the required information is not present in the context,\nreturn null for the missing value.\nDo not invent or hallucinate information.\n\nEXAMPLE:\n\nJob description:\nABC is hiring an ML Engineer with 5 years of experience\nin machine learning and Python.\n\nOutput:\n{\n    "company": "ABC",\n    "role": "ML Engineer",\n    "years_experience_required": 5\n}\n\nFORMAT:\nReturn ONLY valid JSON using exactly these fields:\n\n{\n    "company": "string or null",\n    "role": "string or null",\n    "years_experience_required": "integer or null"\n}\n'}, {'role': 'user', 'content': '\nJob description:\n\nHooli is looking for a Junior Frontend Developer. Fresh grads welcome — no prior experience required. We care about curiosity and willingness to learn. JavaScript, React, and CSS fundamentals expected.\n'}]
# strategy name is::: structured
# snippet id is:::: j06
# snippet is:::: Pied Piper Inc. has an opening for a Senior ML Engineer. Compression algorithms background a plus. We typically look for 7+ years in production ML and distributed systems, but exceptional candidates with less are welcome.
# prompt fetched is:::: [{'role': 'system', 'content': '\nROLE:\nYou are a job extraction expert and recruitment assistant.\n\nTASK:\nExtract the hiring company name, job role, and number of years\nof experience required from the job description.\n\nIf the required information is not present in the context,\nreturn null for the missing value.\nDo not invent or hallucinate information.\n\nEXAMPLE:\n\nJob description:\nABC is hiring an ML Engineer with 5 years of experience\nin machine learning and Python.\n\nOutput:\n{\n    "company": "ABC",\n    "role": "ML Engineer",\n    "years_experience_required": 5\n}\n\nFORMAT:\nReturn ONLY valid JSON using exactly these fields:\n\n{\n    "company": "string or null",\n    "role": "string or null",\n    "years_experience_required": "integer or null"\n}\n'}, {'role': 'user', 'content': '\nJob description:\n\nPied Piper Inc. has an opening for a Senior ML Engineer. Compression algorithms background a plus. We typically look for 7+ years in production ML and distributed systems, but exceptional candidates with less are welcome.\n'}]
# strategy name is::: structured
# snippet id is:::: j07
# snippet is:::: We want a builder. Soylent Industries is growing fast. The role is Engineering Manager. About three years leading engineering teams, plus a solid IC background before that. Apply if you've shipped real products.
# prompt fetched is:::: [{'role': 'system', 'content': '\nROLE:\nYou are a job extraction expert and recruitment assistant.\n\nTASK:\nExtract the hiring company name, job role, and number of years\nof experience required from the job description.\n\nIf the required information is not present in the context,\nreturn null for the missing value.\nDo not invent or hallucinate information.\n\nEXAMPLE:\n\nJob description:\nABC is hiring an ML Engineer with 5 years of experience\nin machine learning and Python.\n\nOutput:\n{\n    "company": "ABC",\n    "role": "ML Engineer",\n    "years_experience_required": 5\n}\n\nFORMAT:\nReturn ONLY valid JSON using exactly these fields:\n\n{\n    "company": "string or null",\n    "role": "string or null",\n    "years_experience_required": "integer or null"\n}\n'}, {'role': 'user', 'content': "\nJob description:\n\nWe want a builder. Soylent Industries is growing fast. The role is Engineering Manager. About three years leading engineering teams, plus a solid IC background before that. Apply if you've shipped real products.\n"}]
# strategy name is::: structured
# snippet id is:::: j08
# snippet is:::: Senior UX Researcher at Wonka Confectionery Ltd. You'll design and run user studies for our digital storefront. Five years of UX research experience or equivalent portfolio required.
# prompt fetched is:::: [{'role': 'system', 'content': '\nROLE:\nYou are a job extraction expert and recruitment assistant.\n\nTASK:\nExtract the hiring company name, job role, and number of years\nof experience required from the job description.\n\nIf the required information is not present in the context,\nreturn null for the missing value.\nDo not invent or hallucinate information.\n\nEXAMPLE:\n\nJob description:\nABC is hiring an ML Engineer with 5 years of experience\nin machine learning and Python.\n\nOutput:\n{\n    "company": "ABC",\n    "role": "ML Engineer",\n    "years_experience_required": 5\n}\n\nFORMAT:\nReturn ONLY valid JSON using exactly these fields:\n\n{\n    "company": "string or null",\n    "role": "string or null",\n    "years_experience_required": "integer or null"\n}\n'}, {'role': 'user', 'content': "\nJob description:\n\nSenior UX Researcher at Wonka Confectionery Ltd. You'll design and run user studies for our digital storefront. Five years of UX research experience or equivalent portfolio required.\n"}]
# strategy name is::: structured
# snippet id is:::: j09
# snippet is:::: Stark Industries: Cybersecurity Analyst (mid-level). Three to five years in a SOC environment or equivalent. Familiarity with SIEM tools, incident response runbooks, and basic threat modelling.
# prompt fetched is:::: [{'role': 'system', 'content': '\nROLE:\nYou are a job extraction expert and recruitment assistant.\n\nTASK:\nExtract the hiring company name, job role, and number of years\nof experience required from the job description.\n\nIf the required information is not present in the context,\nreturn null for the missing value.\nDo not invent or hallucinate information.\n\nEXAMPLE:\n\nJob description:\nABC is hiring an ML Engineer with 5 years of experience\nin machine learning and Python.\n\nOutput:\n{\n    "company": "ABC",\n    "role": "ML Engineer",\n    "years_experience_required": 5\n}\n\nFORMAT:\nReturn ONLY valid JSON using exactly these fields:\n\n{\n    "company": "string or null",\n    "role": "string or null",\n    "years_experience_required": "integer or null"\n}\n'}, {'role': 'user', 'content': '\nJob description:\n\nStark Industries: Cybersecurity Analyst (mid-level). Three to five years in a SOC environment or equivalent. Familiarity with SIEM tools, incident response runbooks, and basic threat modelling.\n'}]
# strategy name is::: structured
# snippet id is:::: j10
# snippet is:::: Cyberdyne Systems is hiring. Role: AI/ML Research Scientist. PhD preferred but not required. Strong publication record in deep learning or reinforcement learning. We don't list a specific years requirement — we hire on demonstrated impact.
# prompt fetched is:::: [{'role': 'system', 'content': '\nROLE:\nYou are a job extraction expert and recruitment assistant.\n\nTASK:\nExtract the hiring company name, job role, and number of years\nof experience required from the job description.\n\nIf the required information is not present in the context,\nreturn null for the missing value.\nDo not invent or hallucinate information.\n\nEXAMPLE:\n\nJob description:\nABC is hiring an ML Engineer with 5 years of experience\nin machine learning and Python.\n\nOutput:\n{\n    "company": "ABC",\n    "role": "ML Engineer",\n    "years_experience_required": 5\n}\n\nFORMAT:\nReturn ONLY valid JSON using exactly these fields:\n\n{\n    "company": "string or null",\n    "role": "string or null",\n    "years_experience_required": "integer or null"\n}\n'}, {'role': 'user', 'content': "\nJob description:\n\nCyberdyne Systems is hiring. Role: AI/ML Research Scientist. PhD preferred but not required. Strong publication record in deep learning or reinforcement learning. We don't list a specific years requirement — we hire on demonstrated impact.\n"}]
# strategy name is::: cot
# snippet id is:::: j01
# snippet is:::: Acme Corp is hiring a Senior Software Engineer to join our platform team. The ideal candidate has 5+ years of backend development experience and strong skills in Python and distributed systems.
# prompt fetched is:::: [{'role': 'system', 'content': '\nYou are a careful job extraction expert and recruitment assistant.\n\nTASK:\nAnalyze the job description step by step and identify:\n\n1. The hiring company name\n2. The job role\n3. The required skillset\n4. The minimum number of years of experience required\n\nREASONING RULES:\n- Carefully inspect the full job description before answering.\n- Identify the company name only if it is explicitly stated.\n- Identify the exact job role.\n- Extract only the skillsets mentioned in the job description.\n- Determine the minimum years of experience required.\n- For "5+ years", return 5.\n- For "at least 4 years", return 4.\n- For "around 6 years", return 6.\n- For "about three years", return 3.\n- For a range such as "3-5 years", return 3.\n- If fresh graduates are accepted, return 0.\n- If years of experience are not mentioned, return null.\n- If any other information is missing, return null.\n- Do not guess or hallucinate information.\n\nThink through the extraction carefully before producing the answer,\nbut return ONLY the final JSON result.\n\nFORMAT:\nReturn only valid JSON with exactly these fields:\n\n{\n    "company": "string or null",\n    "role": "string or null",\n    "skillset": "string or null",\n    "years_experience_required": "integer or null"\n}\n'}, {'role': 'user', 'content': '\nAnalyze the following job description carefully:\n\nAcme Corp is hiring a Senior Software Engineer to join our platform team. The ideal candidate has 5+ years of backend development experience and strong skills in Python and distributed systems.\n\nReturn only the final JSON response.\n'}]
# strategy name is::: cot
# snippet id is:::: j02
# snippet is:::: We're looking for a Data Analyst at Northwind Ltd. Reporting to the Head of Analytics, you'll work with SQL, dashboards, and stakeholder requests. 2 years minimum experience preferred.
# prompt fetched is:::: [{'role': 'system', 'content': '\nYou are a careful job extraction expert and recruitment assistant.\n\nTASK:\nAnalyze the job description step by step and identify:\n\n1. The hiring company name\n2. The job role\n3. The required skillset\n4. The minimum number of years of experience required\n\nREASONING RULES:\n- Carefully inspect the full job description before answering.\n- Identify the company name only if it is explicitly stated.\n- Identify the exact job role.\n- Extract only the skillsets mentioned in the job description.\n- Determine the minimum years of experience required.\n- For "5+ years", return 5.\n- For "at least 4 years", return 4.\n- For "around 6 years", return 6.\n- For "about three years", return 3.\n- For a range such as "3-5 years", return 3.\n- If fresh graduates are accepted, return 0.\n- If years of experience are not mentioned, return null.\n- If any other information is missing, return null.\n- Do not guess or hallucinate information.\n\nThink through the extraction carefully before producing the answer,\nbut return ONLY the final JSON result.\n\nFORMAT:\nReturn only valid JSON with exactly these fields:\n\n{\n    "company": "string or null",\n    "role": "string or null",\n    "skillset": "string or null",\n    "years_experience_required": "integer or null"\n}\n'}, {'role': 'user', 'content': "\nAnalyze the following job description carefully:\n\nWe're looking for a Data Analyst at Northwind Ltd. Reporting to the Head of Analytics, you'll work with SQL, dashboards, and stakeholder requests. 2 years minimum experience preferred.\n\nReturn only the final JSON response.\n"}]
# strategy name is::: cot
# snippet id is:::: j03
# snippet is:::: Globex International seeks a Product Manager - Growth. You'll own activation and onboarding metrics across our consumer apps. We're looking for someone with at least 4 years of product management experience in B2C contexts.
# prompt fetched is:::: [{'role': 'system', 'content': '\nYou are a careful job extraction expert and recruitment assistant.\n\nTASK:\nAnalyze the job description step by step and identify:\n\n1. The hiring company name\n2. The job role\n3. The required skillset\n4. The minimum number of years of experience required\n\nREASONING RULES:\n- Carefully inspect the full job description before answering.\n- Identify the company name only if it is explicitly stated.\n- Identify the exact job role.\n- Extract only the skillsets mentioned in the job description.\n- Determine the minimum years of experience required.\n- For "5+ years", return 5.\n- For "at least 4 years", return 4.\n- For "around 6 years", return 6.\n- For "about three years", return 3.\n- For a range such as "3-5 years", return 3.\n- If fresh graduates are accepted, return 0.\n- If years of experience are not mentioned, return null.\n- If any other information is missing, return null.\n- Do not guess or hallucinate information.\n\nThink through the extraction carefully before producing the answer,\nbut return ONLY the final JSON result.\n\nFORMAT:\nReturn only valid JSON with exactly these fields:\n\n{\n    "company": "string or null",\n    "role": "string or null",\n    "skillset": "string or null",\n    "years_experience_required": "integer or null"\n}\n'}, {'role': 'user', 'content': "\nAnalyze the following job description carefully:\n\nGlobex International seeks a Product Manager - Growth. You'll own activation and onboarding metrics across our consumer apps. We're looking for someone with at least 4 years of product management experience in B2C contexts.\n\nReturn only the final JSON response.\n"}]
# strategy name is::: cot
# snippet id is:::: j04
# snippet is:::: Join Initech as a Lead DevOps Engineer. We need a builder, not a maintainer. Around 6 years of hands-on infrastructure work expected, ideally with AWS, Terraform, and modern CI/CD.
# prompt fetched is:::: [{'role': 'system', 'content': '\nYou are a careful job extraction expert and recruitment assistant.\n\nTASK:\nAnalyze the job description step by step and identify:\n\n1. The hiring company name\n2. The job role\n3. The required skillset\n4. The minimum number of years of experience required\n\nREASONING RULES:\n- Carefully inspect the full job description before answering.\n- Identify the company name only if it is explicitly stated.\n- Identify the exact job role.\n- Extract only the skillsets mentioned in the job description.\n- Determine the minimum years of experience required.\n- For "5+ years", return 5.\n- For "at least 4 years", return 4.\n- For "around 6 years", return 6.\n- For "about three years", return 3.\n- For a range such as "3-5 years", return 3.\n- If fresh graduates are accepted, return 0.\n- If years of experience are not mentioned, return null.\n- If any other information is missing, return null.\n- Do not guess or hallucinate information.\n\nThink through the extraction carefully before producing the answer,\nbut return ONLY the final JSON result.\n\nFORMAT:\nReturn only valid JSON with exactly these fields:\n\n{\n    "company": "string or null",\n    "role": "string or null",\n    "skillset": "string or null",\n    "years_experience_required": "integer or null"\n}\n'}, {'role': 'user', 'content': '\nAnalyze the following job description carefully:\n\nJoin Initech as a Lead DevOps Engineer. We need a builder, not a maintainer. Around 6 years of hands-on infrastructure work expected, ideally with AWS, Terraform, and modern CI/CD.\n\nReturn only the final JSON response.\n'}]
# strategy name is::: cot
# snippet id is:::: j05
# snippet is:::: Hooli is looking for a Junior Frontend Developer. Fresh grads welcome — no prior experience required. We care about curiosity and willingness to learn. JavaScript, React, and CSS fundamentals expected.
# prompt fetched is:::: [{'role': 'system', 'content': '\nYou are a careful job extraction expert and recruitment assistant.\n\nTASK:\nAnalyze the job description step by step and identify:\n\n1. The hiring company name\n2. The job role\n3. The required skillset\n4. The minimum number of years of experience required\n\nREASONING RULES:\n- Carefully inspect the full job description before answering.\n- Identify the company name only if it is explicitly stated.\n- Identify the exact job role.\n- Extract only the skillsets mentioned in the job description.\n- Determine the minimum years of experience required.\n- For "5+ years", return 5.\n- For "at least 4 years", return 4.\n- For "around 6 years", return 6.\n- For "about three years", return 3.\n- For a range such as "3-5 years", return 3.\n- If fresh graduates are accepted, return 0.\n- If years of experience are not mentioned, return null.\n- If any other information is missing, return null.\n- Do not guess or hallucinate information.\n\nThink through the extraction carefully before producing the answer,\nbut return ONLY the final JSON result.\n\nFORMAT:\nReturn only valid JSON with exactly these fields:\n\n{\n    "company": "string or null",\n    "role": "string or null",\n    "skillset": "string or null",\n    "years_experience_required": "integer or null"\n}\n'}, {'role': 'user', 'content': '\nAnalyze the following job description carefully:\n\nHooli is looking for a Junior Frontend Developer. Fresh grads welcome — no prior experience required. We care about curiosity and willingness to learn. JavaScript, React, and CSS fundamentals expected.\n\nReturn only the final JSON response.\n'}]
# strategy name is::: cot
# snippet id is:::: j06
# snippet is:::: Pied Piper Inc. has an opening for a Senior ML Engineer. Compression algorithms background a plus. We typically look for 7+ years in production ML and distributed systems, but exceptional candidates with less are welcome.
# prompt fetched is:::: [{'role': 'system', 'content': '\nYou are a careful job extraction expert and recruitment assistant.\n\nTASK:\nAnalyze the job description step by step and identify:\n\n1. The hiring company name\n2. The job role\n3. The required skillset\n4. The minimum number of years of experience required\n\nREASONING RULES:\n- Carefully inspect the full job description before answering.\n- Identify the company name only if it is explicitly stated.\n- Identify the exact job role.\n- Extract only the skillsets mentioned in the job description.\n- Determine the minimum years of experience required.\n- For "5+ years", return 5.\n- For "at least 4 years", return 4.\n- For "around 6 years", return 6.\n- For "about three years", return 3.\n- For a range such as "3-5 years", return 3.\n- If fresh graduates are accepted, return 0.\n- If years of experience are not mentioned, return null.\n- If any other information is missing, return null.\n- Do not guess or hallucinate information.\n\nThink through the extraction carefully before producing the answer,\nbut return ONLY the final JSON result.\n\nFORMAT:\nReturn only valid JSON with exactly these fields:\n\n{\n    "company": "string or null",\n    "role": "string or null",\n    "skillset": "string or null",\n    "years_experience_required": "integer or null"\n}\n'}, {'role': 'user', 'content': '\nAnalyze the following job description carefully:\n\nPied Piper Inc. has an opening for a Senior ML Engineer. Compression algorithms background a plus. We typically look for 7+ years in production ML and distributed systems, but exceptional candidates with less are welcome.\n\nReturn only the final JSON response.\n'}]
# strategy name is::: cot
# snippet id is:::: j07
# snippet is:::: We want a builder. Soylent Industries is growing fast. The role is Engineering Manager. About three years leading engineering teams, plus a solid IC background before that. Apply if you've shipped real products.
# prompt fetched is:::: [{'role': 'system', 'content': '\nYou are a careful job extraction expert and recruitment assistant.\n\nTASK:\nAnalyze the job description step by step and identify:\n\n1. The hiring company name\n2. The job role\n3. The required skillset\n4. The minimum number of years of experience required\n\nREASONING RULES:\n- Carefully inspect the full job description before answering.\n- Identify the company name only if it is explicitly stated.\n- Identify the exact job role.\n- Extract only the skillsets mentioned in the job description.\n- Determine the minimum years of experience required.\n- For "5+ years", return 5.\n- For "at least 4 years", return 4.\n- For "around 6 years", return 6.\n- For "about three years", return 3.\n- For a range such as "3-5 years", return 3.\n- If fresh graduates are accepted, return 0.\n- If years of experience are not mentioned, return null.\n- If any other information is missing, return null.\n- Do not guess or hallucinate information.\n\nThink through the extraction carefully before producing the answer,\nbut return ONLY the final JSON result.\n\nFORMAT:\nReturn only valid JSON with exactly these fields:\n\n{\n    "company": "string or null",\n    "role": "string or null",\n    "skillset": "string or null",\n    "years_experience_required": "integer or null"\n}\n'}, {'role': 'user', 'content': "\nAnalyze the following job description carefully:\n\nWe want a builder. Soylent Industries is growing fast. The role is Engineering Manager. About three years leading engineering teams, plus a solid IC background before that. Apply if you've shipped real products.\n\nReturn only the final JSON response.\n"}]
# strategy name is::: cot
# snippet id is:::: j08
# snippet is:::: Senior UX Researcher at Wonka Confectionery Ltd. You'll design and run user studies for our digital storefront. Five years of UX research experience or equivalent portfolio required.
# prompt fetched is:::: [{'role': 'system', 'content': '\nYou are a careful job extraction expert and recruitment assistant.\n\nTASK:\nAnalyze the job description step by step and identify:\n\n1. The hiring company name\n2. The job role\n3. The required skillset\n4. The minimum number of years of experience required\n\nREASONING RULES:\n- Carefully inspect the full job description before answering.\n- Identify the company name only if it is explicitly stated.\n- Identify the exact job role.\n- Extract only the skillsets mentioned in the job description.\n- Determine the minimum years of experience required.\n- For "5+ years", return 5.\n- For "at least 4 years", return 4.\n- For "around 6 years", return 6.\n- For "about three years", return 3.\n- For a range such as "3-5 years", return 3.\n- If fresh graduates are accepted, return 0.\n- If years of experience are not mentioned, return null.\n- If any other information is missing, return null.\n- Do not guess or hallucinate information.\n\nThink through the extraction carefully before producing the answer,\nbut return ONLY the final JSON result.\n\nFORMAT:\nReturn only valid JSON with exactly these fields:\n\n{\n    "company": "string or null",\n    "role": "string or null",\n    "skillset": "string or null",\n    "years_experience_required": "integer or null"\n}\n'}, {'role': 'user', 'content': "\nAnalyze the following job description carefully:\n\nSenior UX Researcher at Wonka Confectionery Ltd. You'll design and run user studies for our digital storefront. Five years of UX research experience or equivalent portfolio required.\n\nReturn only the final JSON response.\n"}]
# strategy name is::: cot
# snippet id is:::: j09
# snippet is:::: Stark Industries: Cybersecurity Analyst (mid-level). Three to five years in a SOC environment or equivalent. Familiarity with SIEM tools, incident response runbooks, and basic threat modelling.
# ...
# prompt_tokens:::: 91 completion_tokens:::: 36 model:::: gpt-4o-mini
# $0.00003525
# cost incurred is::: 3.525e-05
# Executing parse_response :: ```json
# {
#   "company": "Stark Industries",
#   "role": "Cybersecurity Analyst",
#   "years_experience_required": "3-5"
# }
# ```
# text before loading json {
#   "company": "Stark Industries",
#   "role": "Cybersecurity Analyst",
#   "years_experience_required": "3-5"
# }
# Response parsed is:: {'company': 'Stark Industries', 'role': 'Cybersecurity Analyst', 'years_experience_required': '3-5'}
# Since parsed response is not null mapping the fields
# Company: Stark Industries
# Role: Cybersecurity Analyst
# Years: 3-5
# final parsed response is:: Stark Industries Cybersecurity Analyst 3-5
# parsedresponse is::: {'company': 'Stark Industries', 'role': 'Cybersecurity Analyst', 'years_experience_required': '3-5'}
# Latency: 1.4409 seconds
# response from LLM is::: ChatCompletion(id='chatcmpl-EFfxeguThDTpBatm4IpMo9Plk72NA', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='{\n    "company": "Acme Corp",\n    "role": "Senior Software Engineer",\n    "years_experience_required": 5\n}', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1787404926, model='gpt-4o-mini-2024-07-18', object='chat.completion', service_tier='default', system_fingerprint='fp_c73dd82b09', usage=CompletionUsage(completion_tokens=30, prompt_tokens=211, total_tokens=241, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# response usage from LLM is::: CompletionUsage(completion_tokens=30, prompt_tokens=211, total_tokens=241, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))
# prompt_tokens:::: 211 completion_tokens:::: 30 model:::: gpt-4o-mini
# $0.00004965
# cost incurred is::: 4.965e-05
# Executing parse_response :: {
#     "company": "Acme Corp",
#     "role": "Senior Software Engineer",
#     "years_experience_required": 5
# }
# text before loading json {
#     "company": "Acme Corp",
#     "role": "Senior Software Engineer",
#     "years_experience_required": 5
# }
# Response parsed is:: {'company': 'Acme Corp', 'role': 'Senior Software Engineer', 'years_experience_required': 5}
# Since parsed response is not null mapping the fields
# Company: Acme Corp
# Role: Senior Software Engineer
# Years: 5
# final parsed response is:: Acme Corp Senior Software Engineer 5
# parsedresponse is::: {'company': 'Acme Corp', 'role': 'Senior Software Engineer', 'years_experience_required': 5}
# Latency: 1.4754 seconds
# response from LLM is::: ChatCompletion(id='chatcmpl-EFfxeyjEKh5BkkNW4Kj3lGukOoqOA', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='{\n    "company": "Northwind Ltd",\n    "role": "Data Analyst",\n    "years_experience_required": 2\n}', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1787404926, model='gpt-4o-mini-2024-07-18', object='chat.completion', service_tier='default', system_fingerprint='fp_9709ac0e8b', usage=CompletionUsage(completion_tokens=29, prompt_tokens=165, total_tokens=194, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# response usage from LLM is::: CompletionUsage(completion_tokens=29, prompt_tokens=165, total_tokens=194, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))
# prompt_tokens:::: 165 completion_tokens:::: 29 model:::: gpt-4o-mini
# $0.00004215
# cost incurred is::: 4.2149999999999995e-05
# Executing parse_response :: {
#     "company": "Northwind Ltd",
#     "role": "Data Analyst",
#     "years_experience_required": 2
# }
# text before loading json {
#     "company": "Northwind Ltd",
#     "role": "Data Analyst",
#     "years_experience_required": 2
# }
# Response parsed is:: {'company': 'Northwind Ltd', 'role': 'Data Analyst', 'years_experience_required': 2}
# Since parsed response is not null mapping the fields
# Company: Northwind Ltd
# Role: Data Analyst
# Years: 2
# final parsed response is:: Northwind Ltd Data Analyst 2
# parsedresponse is::: {'company': 'Northwind Ltd', 'role': 'Data Analyst', 'years_experience_required': 2}
# Latency: 1.4883 seconds
# response from LLM is::: ChatCompletion(id='chatcmpl-EFfxetVY3OWxbblzvLQIZEMtUEwZ3', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='{\n    "company": "Acme Corp",\n    "role": "Senior Software Engineer",\n    "skillset": "Python, distributed systems",\n    "years_experience_required": 5\n}', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1787404926, model='gpt-4o-mini-2024-07-18', object='chat.completion', service_tier='default', system_fingerprint='fp_788bf556eb', usage=CompletionUsage(completion_tokens=41, prompt_tokens=350, total_tokens=391, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# response usage from LLM is::: CompletionUsage(completion_tokens=41, prompt_tokens=350, total_tokens=391, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))
# prompt_tokens:::: 350 completion_tokens:::: 41 model:::: gpt-4o-mini
# $0.00007710
# cost incurred is::: 7.709999999999999e-05
# Executing parse_response :: {
#     "company": "Acme Corp",
#     "role": "Senior Software Engineer",
#     "skillset": "Python, distributed systems",
#     "years_experience_required": 5
# }
# text before loading json {
#     "company": "Acme Corp",
#     "role": "Senior Software Engineer",
#     "skillset": "Python, distributed systems",
#     "years_experience_required": 5
# }
# Response parsed is:: {'company': 'Acme Corp', 'role': 'Senior Software Engineer', 'skillset': 'Python, distributed systems', 'years_experience_required': 5}
# Since parsed response is not null mapping the fields
# Company: Acme Corp
# Role: Senior Software Engineer
# Years: 5
# final parsed response is:: Acme Corp Senior Software Engineer 5
# parsedresponse is::: {'company': 'Acme Corp', 'role': 'Senior Software Engineer', 'skillset': 'Python, distributed systems', 'years_experience_required': 5}
# Latency: 1.5106 seconds
# response from LLM is::: ChatCompletion(id='chatcmpl-EFfxeBgRf0ffPBHHpC4RzxHu1yeDs', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='{\n    "company": "Soylent Industries",\n    "role": "Engineering Manager",\n    "years_experience_required": 3\n}', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1787404926, model='gpt-4o-mini-2024-07-18', object='chat.completion', service_tier='default', system_fingerprint='fp_9709ac0e8b', usage=CompletionUsage(completion_tokens=29, prompt_tokens=169, total_tokens=198, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# response usage from LLM is::: CompletionUsage(completion_tokens=29, prompt_tokens=169, total_tokens=198, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))
# prompt_tokens:::: 169 completion_tokens:::: 29 model:::: gpt-4o-mini
# $0.00004275
# cost incurred is::: 4.2749999999999996e-05
# Executing parse_response :: {
#     "company": "Soylent Industries",
#     "role": "Engineering Manager",
#     "years_experience_required": 3
# }
# text before loading json {
#     "company": "Soylent Industries",
#     "role": "Engineering Manager",
#     "years_experience_required": 3
# }
# Response parsed is:: {'company': 'Soylent Industries', 'role': 'Engineering Manager', 'years_experience_required': 3}
# Since parsed response is not null mapping the fields
# Company: Soylent Industries
# Role: Engineering Manager
# Years: 3
# final parsed response is:: Soylent Industries Engineering Manager 3
# parsedresponse is::: {'company': 'Soylent Industries', 'role': 'Engineering Manager', 'years_experience_required': 3}
# Latency: 1.5519 seconds
# response from LLM is::: ChatCompletion(id='chatcmpl-EFfxeiZBPF7JqYeXMazbzgQNYMQuQ', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='{\n    "company": "Cyberdyne Systems",\n    "role": "AI/ML Research Scientist",\n    "skillset": "Strong publication record in deep learning or reinforcement learning",\n    "years_experience_required": null\n}', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1787404926, model='gpt-4o-mini-2024-07-18', object='chat.completion', service_tier='default', system_fingerprint='fp_788bf556eb', usage=CompletionUsage(completion_tokens=48, prompt_tokens=360, total_tokens=408, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# response usage from LLM is::: CompletionUsage(completion_tokens=48, prompt_tokens=360, total_tokens=408, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))
# prompt_tokens:::: 360 completion_tokens:::: 48 model:::: gpt-4o-mini
# $0.00008280
# cost incurred is::: 8.28e-05
# Executing parse_response :: {
#     "company": "Cyberdyne Systems",
#     "role": "AI/ML Research Scientist",
#     "skillset": "Strong publication record in deep learning or reinforcement learning",
#     "years_experience_required": null
# }
# text before loading json {
#     "company": "Cyberdyne Systems",
#     "role": "AI/ML Research Scientist",
#     "skillset": "Strong publication record in deep learning or reinforcement learning",
#     "years_experience_required": null
# }
# Response parsed is:: {'company': 'Cyberdyne Systems', 'role': 'AI/ML Research Scientist', 'skillset': 'Strong publication record in deep learning or reinforcement learning', 'years_experience_required': None}
# Since parsed response is not null mapping the fields
# Company: Cyberdyne Systems
# Role: AI/ML Research Scientist
# Years: None
# final parsed response is:: Cyberdyne Systems AI/ML Research Scientist None
# parsedresponse is::: {'company': 'Cyberdyne Systems', 'role': 'AI/ML Research Scientist', 'skillset': 'Strong publication record in deep learning or reinforcement learning', 'years_experience_required': None}
# Latency: 1.5864 seconds
# response from LLM is::: ChatCompletion(id='chatcmpl-EFfxe0DtLOfg8FvPwr3qrepxDS2OF', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='{\n    "company": "Soylent Industries",\n    "role": "Engineering Manager",\n    "years_experience_required": 3\n}', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1787404926, model='gpt-4o-mini-2024-07-18', object='chat.completion', service_tier='default', system_fingerprint='fp_c73dd82b09', usage=CompletionUsage(completion_tokens=29, prompt_tokens=215, total_tokens=244, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# response usage from LLM is::: CompletionUsage(completion_tokens=29, prompt_tokens=215, total_tokens=244, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))
# prompt_tokens:::: 215 completion_tokens:::: 29 model:::: gpt-4o-mini
# $0.00004965
# cost incurred is::: 4.965e-05
# Executing parse_response :: {
#     "company": "Soylent Industries",
#     "role": "Engineering Manager",
#     "years_experience_required": 3
# }
# text before loading json {
#     "company": "Soylent Industries",
#     "role": "Engineering Manager",
#     "years_experience_required": 3
# }
# Response parsed is:: {'company': 'Soylent Industries', 'role': 'Engineering Manager', 'years_experience_required': 3}
# Since parsed response is not null mapping the fields
# Company: Soylent Industries
# Role: Engineering Manager
# Years: 3
# final parsed response is:: Soylent Industries Engineering Manager 3
# parsedresponse is::: {'company': 'Soylent Industries', 'role': 'Engineering Manager', 'years_experience_required': 3}
# Latency: 1.7713 seconds
# response from LLM is::: ChatCompletion(id='chatcmpl-EFfxfcJOJieIRLxu4yVll2DrjofOQ', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='{\n    "company": "Pied Piper Inc.",\n    "role": "Senior ML Engineer",\n    "skillset": "Compression algorithms background",\n    "years_experience_required": 7\n}', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1787404927, model='gpt-4o-mini-2024-07-18', object='chat.completion', service_tier='default', system_fingerprint='fp_788bf556eb', usage=CompletionUsage(completion_tokens=41, prompt_tokens=357, total_tokens=398, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# response usage from LLM is::: CompletionUsage(completion_tokens=41, prompt_tokens=357, total_tokens=398, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))
# prompt_tokens:::: 357 completion_tokens:::: 41 model:::: gpt-4o-mini
# $0.00007815
# cost incurred is::: 7.815e-05
# Executing parse_response :: {
#     "company": "Pied Piper Inc.",
#     "role": "Senior ML Engineer",
#     "skillset": "Compression algorithms background",
#     "years_experience_required": 7
# }
# text before loading json {
#     "company": "Pied Piper Inc.",
#     "role": "Senior ML Engineer",
#     "skillset": "Compression algorithms background",
#     "years_experience_required": 7
# }
# Response parsed is:: {'company': 'Pied Piper Inc.', 'role': 'Senior ML Engineer', 'skillset': 'Compression algorithms background', 'years_experience_required': 7}
# Since parsed response is not null mapping the fields
# Company: Pied Piper Inc.
# Role: Senior ML Engineer
# Years: 7
# final parsed response is:: Pied Piper Inc. Senior ML Engineer 7
# parsedresponse is::: {'company': 'Pied Piper Inc.', 'role': 'Senior ML Engineer', 'skillset': 'Compression algorithms background', 'years_experience_required': 7}
# Got 40 results.
# Results written to: ../data/output4.txt

# %% [markdown]
# ## Step 4 — Score against the golden set
#
# Three scores per (strategy × snippet) pair:
#
# 1. **accuracy** — how many of 3 fields match (0, 1, 2, or 3)?
# 2. **parse_success** — did the response parse cleanly?
# 3. **llm_judge_score** — 1-4 score from gpt-4o-as-judge
#
# **TODO:** implement the three score functions.

# %%
def score_accuracy(extracted: dict | None, gold: dict) -> int:
    """Compare 3 fields. Case-insensitive, whitespace-trimmed for strings. Return 0, 1, 2, or 3."""
    # TODO: count exact matches (with normalisation)
    
    if extracted is None:
        return 0

    score = 0

    # Compare company
    extracted_company = extracted.get("company")
    gold_company = gold.get("company")
    print("extraced companu is:::",extracted_company)
    print("gold_account is:::",gold_company)

    if isinstance(extracted_company, str):
        extracted_company = extracted_company.strip().lower()

    if isinstance(gold_company, str):
        gold_company = gold_company.strip().lower()

    if extracted_company == gold_company:
        score = score + 1

    # Compare role
    extracted_role = extracted.get("role")
    gold_role = gold.get("role")

    if isinstance(extracted_role, str):
        extracted_role = extracted_role.strip().lower()

    if isinstance(gold_role, str):
        gold_role = gold_role.strip().lower()

    if extracted_role == gold_role:
        score = score + 1

    # Compare years
    extracted_years = extracted.get(
        "years_experience_required"
    )

    gold_years = gold.get(
        "years_experience_required"
    )

    if extracted_years == gold_years:
        score = score + 1

    return score

RUBRIC = """Evaluate the answer on three dimensions. For each, give a score 1-4:

ACCURACY (1-4)
  4 = fully correct given the corpus
  3 = mostly correct, minor issues
  2 = partially correct, significant issues
  1 = incorrect or misleading

GROUNDEDNESS (1-4)
  4 = every claim traces to the corpus
  3 = mostly grounded, small unsupported additions
  2 = mix of grounded and invented content
  1 = substantially invented or hallucinated
  
FORMAT (1-4)
  4 = clear, appropriately concise, well-structured
  3 = clear but slightly verbose or terse
  2 = confusing structure or wrong length
  1 = badly formatted, hard to read"""

print(RUBRIC)

class JudgeVerdict(BaseModel):
    accuracy: int      = Field(ge=1, le=4)
    groundedness: int  = Field(ge=1, le=4)
    format_score: int  = Field(ge=1, le=4)
    reasoning: str     = Field(min_length=20, max_length=500)

print("Schema fields:")
for name, field in JudgeVerdict.model_fields.items():
    print(f"  {name:15s}  {field.annotation.__name__}")





async def score_llm_judge(snippet_text: str, extracted: dict | None, gold: dict, ideal: str = "") -> JudgeVerdict:
    """Use gpt-4o as a judge. Return integer 1-4.
    
    Rubric (suggested):
      4 — all three fields correct
      3 — two of three correct, no fabricated data
      2 — one of three correct, or fabricated a field
      1 — none correct or unparsable
    """
    # TODO: prompt the judge with both the gold and the extracted, ask for a 1-4 score
    
    if extracted is None:
        return JudgeVerdict(
            accuracy=1,
            groundedness=1,
            format_score=1,
            reasoning="The extracted response is missing or could not be parsed."
        )
    resp = await client.chat.completions.parse(
        model=JUDGE_MODEL,
        temperature=0.0,
        response_format=JudgeVerdict,
        messages=[
            {"role": "system", "content":
                f"You are a strict evaluator of LLM answers.\n\n{RUBRIC}\n\n"
                "Return your scores and a brief reasoning explaining the scores."},
        {
                "role": "user",
                "content": f"""
Original job snippet:
{snippet_text}

Golden answer:
{json.dumps(gold, indent=2)}

Candidate extracted answer:
{json.dumps(extracted, indent=2)}
"""
            },
        ],
    )
    print("Judge response is::",resp)

    # resp = ""
    # raw_response = {
    # "id": "chatcmpl-EEGWRe7DU51LvNoTIfHOAyUTECjy3",

    # "content": """```json
    # {
    #   "company": "Acme Corp",
    #   "role": "Senior Software Engineer",
    #   "years_experience_required": 5
    # }```""",

    # "model": "gpt-4o-mini-2024-07-18",

    # "usage": {
    #     "completion_tokens": 34,
    #     "prompt_tokens": 88,
    #     "total_tokens": 122
    # }
    # }
    return resp.choices[0].message.parsed
# Out:
# Evaluate the answer on three dimensions. For each, give a score 1-4:
#
# ACCURACY (1-4)
#   4 = fully correct given the corpus
#   3 = mostly correct, minor issues
#   2 = partially correct, significant issues
#   1 = incorrect or misleading
#
# GROUNDEDNESS (1-4)
#   4 = every claim traces to the corpus
#   3 = mostly grounded, small unsupported additions
#   2 = mix of grounded and invented content
#   1 = substantially invented or hallucinated
#
# FORMAT (1-4)
#   4 = clear, appropriately concise, well-structured
#   3 = clear but slightly verbose or terse
#   2 = confusing structure or wrong length
#   1 = badly formatted, hard to read
# Schema fields:
#   accuracy         int
#   groundedness     int
#   format_score     int
#   reasoning        str

# %%
# Apply scoring to all 40 results
# TODO: loop through results, attach accuracy + parse_success + llm_judge_score to each row
# LLM Judge score

print(type(golden))
print(golden)

print(type(snippets))
print(type(snippets[0]))
print(snippets[0])


golden_lookup = golden

snippet_lookup = {
    item["id"]: item["snippet"]
    for item in snippets
}

print("Golden j01:", golden_lookup["j01"])
print("Snippet j01:", snippet_lookup["j01"])


scored = []

for result in results:

    if isinstance(result, Exception):
        print("Skipping failed result:", result)
        continue

    goldenset_record = golden_lookup.get(result["id"])

    if goldenset_record is None:
        print("Golden record not found:", result["id"])
        continue

    extracted = {
        "company": result["company"],
        "role": result["role"],
        "years_experience_required":
            result["years_experience_required"]
    }

    accuracy_score = score_accuracy(
        extracted,
        goldenset_record
    )

    parse_success = (
        1 if result.get("parsed_response") is not None else 0
    )

    snippet_text = snippet_lookup[result["id"]]

    verdict = await score_llm_judge(
        snippet_text,
        extracted,
        goldenset_record
    )

    scored.append({
        "id": result["id"],
        "strategy": result["strategy"],
        "accuracy": accuracy_score,
        "parse_success": parse_success,
        "llm_judge_score": verdict.accuracy,
        "groundedness": verdict.groundedness,
        "format_score": verdict.format_score,
        "judge_reasoning": verdict.reasoning,
        "cost_usd": result["cost_usd"],
        "latency_s": result["latency_seconds"]
    })

print("Total scored records:", len(scored))

# Write results to output file
OUTPUT_FILE = DATA_DIR / "judge_response1.txt"

with open(OUTPUT_FILE, "w", encoding="utf-8") as f:
    for result in scored:
        f.write(str(result))
        f.write("\n")

print("Results written to:", OUTPUT_FILE)
# Out:
# <class 'dict'>
# {'j01': {'id': 'j01', 'company': 'Acme Corp', 'role': 'Senior Software Engineer', 'years_experience_required': 5, 'notes': 'clean — clear company + role + years'}, 'j02': {'id': 'j02', 'company': 'Northwind Ltd', 'role': 'Data Analyst', 'years_experience_required': 2, 'notes': 'clean — preferred used but still a stated minimum'}, 'j03': {'id': 'j03', 'company': 'Globex International', 'role': 'Product Manager - Growth', 'years_experience_required': 4, 'notes': "clean — 'at least 4 years'"}, 'j04': {'id': 'j04', 'company': 'Initech', 'role': 'Lead DevOps Engineer', 'years_experience_required': 6, 'notes': "slightly fuzzy — 'around 6 years' — accept 6"}, 'j05': {'id': 'j05', 'company': 'Hooli', 'role': 'Junior Frontend Developer', 'years_experience_required': 0, 'notes': 'edge — fresh grads OK = 0 years'}, 'j06': {'id': 'j06', 'company': 'Pied Piper Inc.', 'role': 'Senior ML Engineer', 'years_experience_required': 7, 'notes': "fuzzy — '7+ years' typically taken as 7; exceptional candidates clause is colour text"}, 'j07': {'id': 'j07', 'company': 'Soylent Industries', 'role': 'Engineering Manager', 'years_experience_required': 3, 'notes': "spelled-out number — 'about three years' → 3"}, 'j08': {'id': 'j08', 'company': 'Wonka Confectionery Ltd', 'role': 'Senior UX Researcher', 'years_experience_required': 5, 'notes': "clean — 'five years' → 5"}, 'j09': {'id': 'j09', 'company': 'Stark Industries', 'role': 'Cybersecurity Analyst', 'years_experience_required': 3, 'notes': "range 3-5 — take the minimum, 3. Accept 3 or 'between 3 and 5'."}, 'j10': {'id': 'j10', 'company': 'Cyberdyne Systems', 'role': 'AI/ML Research Scientist', 'years_experience_required': None, 'notes': 'edge — no years stated. Correct answer: null. Penalise if model fabricates a number.'}}
# <class 'list'>
# <class 'dict'>
# {'id': 'j01', 'snippet': 'Acme Corp is hiring a Senior Software Engineer to join our platform team. The ideal candidate has 5+ years of backend development experience and strong skills in Python and distributed systems.'}
# Golden j01: {'id': 'j01', 'company': 'Acme Corp', 'role': 'Senior Software Engineer', 'years_experience_required': 5, 'notes': 'clean — clear company + role + years'}
# Snippet j01: Acme Corp is hiring a Senior Software Engineer to join our platform team. The ideal candidate has 5+ years of backend development experience and strong skills in Python and distributed systems.
# extraced companu is::: Acme Corp
# gold_account is::: Acme Corp
# Judge response is:: ParsedChatCompletion[~ResponseFormatT](id='chatcmpl-EFfyAJVRWba1VpHjxxdvwnvVpcUIB', choices=[ParsedChoice[~ResponseFormatT](finish_reason='stop', index=0, logprobs=None, message=ParsedChatCompletionMessage[~ResponseFormatT](content='{"accuracy":4,"groundedness":4,"format_score":4,"reasoning":"The candidate\'s extracted answer accurately captures all the key details from the original job snippet: the company name (Acme Corp), the role (Senior Software Engineer), and the years of experience required (5). These details are directly supported by the text in the job snippet, ensuring full accuracy and groundedness. The format is clear and concise, matching the structure of the golden answer without unnecessary information, thus earning a perfect score in all dimensions."}', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None, parsed=JudgeVerdict(accuracy=4, groundedness=4, format_score=4, reasoning="The candidate's extracted answer accurately captures all the key details from the original job snippet: the company name (Acme Corp), the role (Senior Software Engineer), and the years of experience required (5). These details are directly supported by the text in the job snippet, ensuring full accuracy and groundedness. The format is clear and concise, matching the structure of the golden answer without unnecessary information, thus earning a perfect score in all dimensions.")))], created=1787404958, model='gpt-4o-2024-08-06', object='chat.completion', service_tier='default', system_fingerprint='fp_17e3c4f467', usage=CompletionUsage(completion_tokens=108, prompt_tokens=412, total_tokens=520, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# extraced companu is::: Northwind Ltd.
# gold_account is::: Northwind Ltd
# Judge response is:: ParsedChatCompletion[~ResponseFormatT](id='chatcmpl-EFfyCzAZWycIfXXiRg0JZ0sVfnLkO', choices=[ParsedChoice[~ResponseFormatT](finish_reason='stop', index=0, logprobs=None, message=ParsedChatCompletionMessage[~ResponseFormatT](content='{"accuracy":4,"groundedness":4,"format_score":4,"reasoning":"The candidate\'s extracted answer accurately reflects the information provided in the original job snippet. The company name, role, and years of experience required are correctly identified and match the golden answer. The extracted answer is fully grounded in the provided text, with no additional or invented content. The format is clear and concise, presenting the information in a structured manner that aligns with the expected output."}', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None, parsed=JudgeVerdict(accuracy=4, groundedness=4, format_score=4, reasoning="The candidate's extracted answer accurately reflects the information provided in the original job snippet. The company name, role, and years of experience required are correctly identified and match the golden answer. The extracted answer is fully grounded in the provided text, with no additional or invented content. The format is clear and concise, presenting the information in a structured manner that aligns with the expected output.")))], created=1787404960, model='gpt-4o-2024-08-06', object='chat.completion', service_tier='default', system_fingerprint='fp_17e3c4f467', usage=CompletionUsage(completion_tokens=95, prompt_tokens=411, total_tokens=506, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# extraced companu is::: Globex International
# gold_account is::: Globex International
# Judge response is:: ParsedChatCompletion[~ResponseFormatT](id='chatcmpl-EFfyDcTPdzCNzDDFyMZCLd1NfvS7C', choices=[ParsedChoice[~ResponseFormatT](finish_reason='stop', index=0, logprobs=None, message=ParsedChatCompletionMessage[~ResponseFormatT](content='{"accuracy":4,"groundedness":4,"format_score":4,"reasoning":"The candidate\'s extracted answer is fully accurate and matches the information provided in the original job snippet. The company, role, and years of experience required are correctly identified. The extracted answer is also fully grounded in the corpus, as all elements are directly traceable to the original text. The format is clear, concise, and well-structured, making it easy to read and understand. The absence of the \'notes\' field in the candidate\'s answer does not affect the accuracy or the "}', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None, parsed=JudgeVerdict(accuracy=4, groundedness=4, format_score=4, reasoning="The candidate's extracted answer is fully accurate and matches the information provided in the original job snippet. The company, role, and years of experience required are correctly identified. The extracted answer is also fully grounded in the corpus, as all elements are directly traceable to the original text. The format is clear, concise, and well-structured, making it easy to read and understand. The absence of the 'notes' field in the candidate's answer does not affect the accuracy or the ")))], created=1787404961, model='gpt-4o-2024-08-06', object='chat.completion', service_tier='default', system_fingerprint='fp_17e3c4f467', usage=CompletionUsage(completion_tokens=117, prompt_tokens=419, total_tokens=536, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# extraced companu is::: Initech
# gold_account is::: Initech
# Judge response is:: ParsedChatCompletion[~ResponseFormatT](id='chatcmpl-EFfyFW67Kj52So4omvvRFRYL6wgmh', choices=[ParsedChoice[~ResponseFormatT](finish_reason='stop', index=0, logprobs=None, message=ParsedChatCompletionMessage[~ResponseFormatT](content='{"accuracy":4,"groundedness":4,"format_score":4,"reasoning":"The candidate\'s extracted answer accurately captures the key details from the original job snippet: the company (Initech), the role (Lead DevOps Engineer), and the years of experience required (6). These elements are directly supported by the text in the job snippet. The format is clear and concise, matching the expected structure for such an extraction task. The omission of the note about the fuzziness of the experience requirement does not affect the accuracy or groundedness of the extracted, "}', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None, parsed=JudgeVerdict(accuracy=4, groundedness=4, format_score=4, reasoning="The candidate's extracted answer accurately captures the key details from the original job snippet: the company (Initech), the role (Lead DevOps Engineer), and the years of experience required (6). These elements are directly supported by the text in the job snippet. The format is clear and concise, matching the expected structure for such an extraction task. The omission of the note about the fuzziness of the experience requirement does not affect the accuracy or groundedness of the extracted, ")))], created=1787404963, model='gpt-4o-2024-08-06', object='chat.completion', service_tier='default', system_fingerprint='fp_17e3c4f467', usage=CompletionUsage(completion_tokens=115, prompt_tokens=427, total_tokens=542, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# extraced companu is::: Hooli
# gold_account is::: Hooli
# Judge response is:: ParsedChatCompletion[~ResponseFormatT](id='chatcmpl-EFfyH2FOnGr0bSJ47Z0S5lRBUmjI2', choices=[ParsedChoice[~ResponseFormatT](finish_reason='stop', index=0, logprobs=None, message=ParsedChatCompletionMessage[~ResponseFormatT](content='{"accuracy":4,"groundedness":4,"format_score":4,"reasoning":"The candidate\'s extracted answer accurately reflects the information provided in the original job snippet. The company, role, and years of experience required are correctly identified and match the golden answer. The extracted answer is fully grounded in the provided text, with no additional or invented content. The format is clear, concise, and well-structured, making it easy to read and understand. Therefore, the scores for accuracy, groundedness, and format are all 4."}', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None, parsed=JudgeVerdict(accuracy=4, groundedness=4, format_score=4, reasoning="The candidate's extracted answer accurately reflects the information provided in the original job snippet. The company, role, and years of experience required are correctly identified and match the golden answer. The extracted answer is fully grounded in the provided text, with no additional or invented content. The format is clear, concise, and well-structured, making it easy to read and understand. Therefore, the scores for accuracy, groundedness, and format are all 4.")))], created=1787404965, model='gpt-4o-2024-08-06', object='chat.completion', service_tier='default', system_fingerprint='fp_17e3c4f467', usage=CompletionUsage(completion_tokens=110, prompt_tokens=416, total_tokens=526, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# extraced companu is::: Pied Piper Inc.
# gold_account is::: Pied Piper Inc.
# Judge response is:: ParsedChatCompletion[~ResponseFormatT](id='chatcmpl-EFfyIQevYvgUeF4bQ1w4poYh5HauY', choices=[ParsedChoice[~ResponseFormatT](finish_reason='stop', index=0, logprobs=None, message=ParsedChatCompletionMessage[~ResponseFormatT](content='{"accuracy":4,"groundedness":4,"format_score":4,"reasoning":"The candidate\'s extracted answer accurately captures the key details from the original job snippet: the company name, the role, and the years of experience required. The extracted answer is fully grounded in the provided text, as it directly reflects the information given in the job snippet. The format is clear and concise, matching the expected structure for such an extraction task. The candidate\'s answer omits the additional note about exceptional candidates, but this is consistent with the \'f" \n\n}', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None, parsed=JudgeVerdict(accuracy=4, groundedness=4, format_score=4, reasoning="The candidate's extracted answer accurately captures the key details from the original job snippet: the company name, the role, and the years of experience required. The extracted answer is fully grounded in the provided text, as it directly reflects the information given in the job snippet. The format is clear and concise, matching the expected structure for such an extraction task. The candidate's answer omits the additional note about exceptional candidates, but this is consistent with the 'f")))], created=1787404966, model='gpt-4o-2024-08-06', object='chat.completion', service_tier='default', system_fingerprint='fp_17e3c4f467', usage=CompletionUsage(completion_tokens=113, prompt_tokens=433, total_tokens=546, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# extraced companu is::: Soylent Industries
# gold_account is::: Soylent Industries
# Judge response is:: ParsedChatCompletion[~ResponseFormatT](id='chatcmpl-EFfyKhLwmQnsJNWJRdkuUTvyYTm9K', choices=[ParsedChoice[~ResponseFormatT](finish_reason='stop', index=0, logprobs=None, message=ParsedChatCompletionMessage[~ResponseFormatT](content='{"accuracy":4,"groundedness":4,"format_score":4,"reasoning":"The candidate\'s extracted answer accurately captures the key details from the original job snippet: the company name, the role, and the years of experience required. The golden answer includes an additional note about the conversion of \'about three years\' to the numeral \'3\', but this does not affect the accuracy of the candidate\'s extraction. The extracted answer is fully grounded in the provided text, and the format is clear and concise, matching the expected structure for such an extraction."}', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None, parsed=JudgeVerdict(accuracy=4, groundedness=4, format_score=4, reasoning="The candidate's extracted answer accurately captures the key details from the original job snippet: the company name, the role, and the years of experience required. The golden answer includes an additional note about the conversion of 'about three years' to the numeral '3', but this does not affect the accuracy of the candidate's extraction. The extracted answer is fully grounded in the provided text, and the format is clear and concise, matching the expected structure for such an extraction.")))], created=1787404968, model='gpt-4o-2024-08-06', object='chat.completion', service_tier='default', system_fingerprint='fp_17e3c4f467', usage=CompletionUsage(completion_tokens=113, prompt_tokens=422, total_tokens=535, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# extraced companu is::: Wonka Confectionery Ltd.
# gold_account is::: Wonka Confectionery Ltd
# Judge response is:: ParsedChatCompletion[~ResponseFormatT](id='chatcmpl-EFfyLwxDacJeVFHXv9RNOtfVbdTy2', choices=[ParsedChoice[~ResponseFormatT](finish_reason='stop', index=0, logprobs=None, message=ParsedChatCompletionMessage[~ResponseFormatT](content='{"accuracy":4,"groundedness":4,"format_score":4,"reasoning":"The candidate\'s extracted answer accurately captures the key details from the original job snippet: the company name, role, and years of experience required. All information is directly traceable to the provided text, ensuring full groundedness. The format is clear and concise, matching the structure of the golden answer, albeit without the additional \'notes\' field, which is not essential for the core extraction."}', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None, parsed=JudgeVerdict(accuracy=4, groundedness=4, format_score=4, reasoning="The candidate's extracted answer accurately captures the key details from the original job snippet: the company name, role, and years of experience required. All information is directly traceable to the provided text, ensuring full groundedness. The format is clear and concise, matching the structure of the golden answer, albeit without the additional 'notes' field, which is not essential for the core extraction.")))], created=1787404969, model='gpt-4o-2024-08-06', object='chat.completion', service_tier='default', system_fingerprint='fp_17e3c4f467', usage=CompletionUsage(completion_tokens=97, prompt_tokens=422, total_tokens=519, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# extraced companu is::: Stark Industries
# gold_account is::: Stark Industries
# Judge response is:: ParsedChatCompletion[~ResponseFormatT](id='chatcmpl-EFfyNs8YTQkgStFQ3IodmcZdDsLZB', choices=[ParsedChoice[~ResponseFormatT](finish_reason='stop', index=0, logprobs=None, message=ParsedChatCompletionMessage[~ResponseFormatT](content='{"accuracy":4,"groundedness":4,"format_score":4,"reasoning":"The candidate\'s extracted answer is fully accurate and grounded in the original job snippet. The company name, role, and years of experience required are correctly extracted. The format is clear and concise, matching the expected structure for such data extraction tasks. The range for years of experience is correctly noted as \\"3-5,\\" which aligns with the original job snippet\'s requirement of \\"Three to five years.\\" Therefore, the scores for accuracy, groundedness, and format are all 4."}', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None, parsed=JudgeVerdict(accuracy=4, groundedness=4, format_score=4, reasoning='The candidate\'s extracted answer is fully accurate and grounded in the original job snippet. The company name, role, and years of experience required are correctly extracted. The format is clear and concise, matching the expected structure for such data extraction tasks. The range for years of experience is correctly noted as "3-5," which aligns with the original job snippet\'s requirement of "Three to five years." Therefore, the scores for accuracy, groundedness, and format are all 4.')))], created=1787404971, model='gpt-4o-2024-08-06', object='chat.completion', service_tier='default', system_fingerprint='fp_17e3c4f467', usage=CompletionUsage(completion_tokens=116, prompt_tokens=434, total_tokens=550, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# extraced companu is::: Cyberdyne Systems
# gold_account is::: Cyberdyne Systems
# Judge response is:: ParsedChatCompletion[~ResponseFormatT](id='chatcmpl-EFfyPnKjYboqry1tRDxY5Y2tNT8Sg', choices=[ParsedChoice[~ResponseFormatT](finish_reason='stop', index=0, logprobs=None, message=ParsedChatCompletionMessage[~ResponseFormatT](content='{"accuracy":4,"groundedness":4,"format_score":4,"reasoning":"The candidate\'s extracted answer accurately reflects the information provided in the original job snippet. The company and role are correctly identified as \\"Cyberdyne Systems\\" and \\"AI/ML Research Scientist,\\" respectively. The years of experience required is noted as \\"not specified,\\" which aligns with the job snippet\'s statement that no specific years requirement is listed. The format is clear and concise, matching the expected structure for such an extraction task."}', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None, parsed=JudgeVerdict(accuracy=4, groundedness=4, format_score=4, reasoning='The candidate\'s extracted answer accurately reflects the information provided in the original job snippet. The company and role are correctly identified as "Cyberdyne Systems" and "AI/ML Research Scientist," respectively. The years of experience required is noted as "not specified," which aligns with the job snippet\'s statement that no specific years requirement is listed. The format is clear and concise, matching the expected structure for such an extraction task.')))], created=1787404973, model='gpt-4o-2024-08-06', object='chat.completion', service_tier='default', system_fingerprint='fp_17e3c4f467', usage=CompletionUsage(completion_tokens=105, prompt_tokens=439, total_tokens=544, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# extraced companu is::: Acme Corp
# gold_account is::: Acme Corp
# Judge response is:: ParsedChatCompletion[~ResponseFormatT](id='chatcmpl-EFfyRkt1lWcK9V8Lpv6QsIVwIOQly', choices=[ParsedChoice[~ResponseFormatT](finish_reason='stop', index=0, logprobs=None, message=ParsedChatCompletionMessage[~ResponseFormatT](content='{"accuracy":4,"groundedness":4,"format_score":4,"reasoning":"The candidate\'s extracted answer accurately captures all the key details from the original job snippet: the company name (Acme Corp), the role (Senior Software Engineer), and the years of experience required (5). These details are directly supported by the text in the job snippet, ensuring full accuracy and groundedness. The format is clear and concise, matching the structure of the golden answer without unnecessary information, thus earning a perfect score in all dimensions."}', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None, parsed=JudgeVerdict(accuracy=4, groundedness=4, format_score=4, reasoning="The candidate's extracted answer accurately captures all the key details from the original job snippet: the company name (Acme Corp), the role (Senior Software Engineer), and the years of experience required (5). These details are directly supported by the text in the job snippet, ensuring full accuracy and groundedness. The format is clear and concise, matching the structure of the golden answer without unnecessary information, thus earning a perfect score in all dimensions.")))], created=1787404975, model='gpt-4o-2024-08-06', object='chat.completion', service_tier='default', system_fingerprint='fp_17e3c4f467', usage=CompletionUsage(completion_tokens=108, prompt_tokens=412, total_tokens=520, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# extraced companu is::: Northwind Ltd
# gold_account is::: Northwind Ltd
# Judge response is:: ParsedChatCompletion[~ResponseFormatT](id='chatcmpl-EFfyTOZgBIDn7C5k65xyS8vNjnqdW', choices=[ParsedChoice[~ResponseFormatT](finish_reason='stop', index=0, logprobs=None, message=ParsedChatCompletionMessage[~ResponseFormatT](content='{"accuracy":4,"groundedness":4,"format_score":4,"reasoning":"The candidate\'s extracted answer accurately captures the key details from the original job snippet, including the company name, role, and years of experience required. The golden answer includes an additional note about the phrasing of the experience requirement, but this does not affect the accuracy of the candidate\'s extraction. The extracted answer is fully grounded in the provided text, and the format is clear and concise, matching the expected structure."}', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None, parsed=JudgeVerdict(accuracy=4, groundedness=4, format_score=4, reasoning="The candidate's extracted answer accurately captures the key details from the original job snippet, including the company name, role, and years of experience required. The golden answer includes an additional note about the phrasing of the experience requirement, but this does not affect the accuracy of the candidate's extraction. The extracted answer is fully grounded in the provided text, and the format is clear and concise, matching the expected structure.")))], created=1787404977, model='gpt-4o-2024-08-06', object='chat.completion', service_tier='default', system_fingerprint='fp_17e3c4f467', usage=CompletionUsage(completion_tokens=102, prompt_tokens=411, total_tokens=513, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# extraced companu is::: Globex International
# gold_account is::: Globex International
# Judge response is:: ParsedChatCompletion[~ResponseFormatT](id='chatcmpl-EFfyV7IGm4yk2TwmqH41KztIiUgyk', choices=[ParsedChoice[~ResponseFormatT](finish_reason='stop', index=0, logprobs=None, message=ParsedChatCompletionMessage[~ResponseFormatT](content='{"accuracy":4,"groundedness":4,"format_score":4,"reasoning":"The candidate\'s extracted answer accurately captures the key details from the original job snippet: the company name, the role, and the years of experience required. These details are fully grounded in the provided text. The format is clear and concise, matching the structure of the golden answer, albeit without the additional note, which is not essential for the core information extraction. Therefore, the scores for accuracy, groundedness, and format are all 4."}', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None, parsed=JudgeVerdict(accuracy=4, groundedness=4, format_score=4, reasoning="The candidate's extracted answer accurately captures the key details from the original job snippet: the company name, the role, and the years of experience required. These details are fully grounded in the provided text. The format is clear and concise, matching the structure of the golden answer, albeit without the additional note, which is not essential for the core information extraction. Therefore, the scores for accuracy, groundedness, and format are all 4.")))], created=1787404979, model='gpt-4o-2024-08-06', object='chat.completion', service_tier='default', system_fingerprint='fp_17e3c4f467', usage=CompletionUsage(completion_tokens=108, prompt_tokens=419, total_tokens=527, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# extraced companu is::: Initech
# gold_account is::: Initech
# Judge response is:: ParsedChatCompletion[~ResponseFormatT](id='chatcmpl-EFfyWoQE81FwZqHTDRVbWNlKNS4lx', choices=[ParsedChoice[~ResponseFormatT](finish_reason='stop', index=0, logprobs=None, message=ParsedChatCompletionMessage[~ResponseFormatT](content='{"accuracy":4,"groundedness":4,"format_score":4,"reasoning":"The candidate\'s extracted answer accurately captures the key details from the original job snippet: the company (Initech), the role (Lead DevOps Engineer), and the years of experience required (6). These details are directly supported by the text in the job snippet. The format is clear and concise, matching the expected structure for such an extraction task. There are no inaccuracies or unsupported claims, and the format is appropriate for the information provided."}', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None, parsed=JudgeVerdict(accuracy=4, groundedness=4, format_score=4, reasoning="The candidate's extracted answer accurately captures the key details from the original job snippet: the company (Initech), the role (Lead DevOps Engineer), and the years of experience required (6). These details are directly supported by the text in the job snippet. The format is clear and concise, matching the expected structure for such an extraction task. There are no inaccuracies or unsupported claims, and the format is appropriate for the information provided.")))], created=1787404980, model='gpt-4o-2024-08-06', object='chat.completion', service_tier='default', system_fingerprint='fp_17e3c4f467', usage=CompletionUsage(completion_tokens=107, prompt_tokens=427, total_tokens=534, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# extraced companu is::: Hooli
# gold_account is::: Hooli
# Judge response is:: ParsedChatCompletion[~ResponseFormatT](id='chatcmpl-EFfyY1BCz9sc8230EbYE0SRurmMJH', choices=[ParsedChoice[~ResponseFormatT](finish_reason='stop', index=0, logprobs=None, message=ParsedChatCompletionMessage[~ResponseFormatT](content='{"accuracy":3,"groundedness":3,"format_score":4,"reasoning":"The candidate\'s extracted answer correctly identifies the company and role, matching the original job snippet. However, it leaves \\"years_experience_required\\" as null, which is less precise than the golden answer\'s explicit \\"0\\" years, indicating fresh grads are welcome. This results in a minor accuracy issue. The groundedness is mostly correct, but the lack of explicit mention of \\"0 years\\" makes it slightly less grounded than the golden answer. The format is clear and well-structured, deserving a"  }', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None, parsed=JudgeVerdict(accuracy=3, groundedness=3, format_score=4, reasoning='The candidate\'s extracted answer correctly identifies the company and role, matching the original job snippet. However, it leaves "years_experience_required" as null, which is less precise than the golden answer\'s explicit "0" years, indicating fresh grads are welcome. This results in a minor accuracy issue. The groundedness is mostly correct, but the lack of explicit mention of "0 years" makes it slightly less grounded than the golden answer. The format is clear and well-structured, deserving a')))], created=1787404982, model='gpt-4o-2024-08-06', object='chat.completion', service_tier='default', system_fingerprint='fp_17e3c4f467', usage=CompletionUsage(completion_tokens=122, prompt_tokens=415, total_tokens=537, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# extraced companu is::: Pied Piper Inc.
# gold_account is::: Pied Piper Inc.
# Judge response is:: ParsedChatCompletion[~ResponseFormatT](id='chatcmpl-EFfyaJjP8QudZ5KnQQsvt9dZRgDtT', choices=[ParsedChoice[~ResponseFormatT](finish_reason='stop', index=0, logprobs=None, message=ParsedChatCompletionMessage[~ResponseFormatT](content='{"accuracy":4,"groundedness":4,"format_score":4,"reasoning":"The candidate\'s extracted answer accurately captures the key details from the original job snippet: the company name, the role, and the years of experience required. The extracted answer is fully grounded in the provided corpus, as it directly reflects the information given in the job snippet. The format is clear and concise, matching the expected structure for such an extraction task. The omission of the notes about the \'exceptional candidates\' clause is acceptable as it is considered color or,"\n\n}', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None, parsed=JudgeVerdict(accuracy=4, groundedness=4, format_score=4, reasoning="The candidate's extracted answer accurately captures the key details from the original job snippet: the company name, the role, and the years of experience required. The extracted answer is fully grounded in the provided corpus, as it directly reflects the information given in the job snippet. The format is clear and concise, matching the expected structure for such an extraction task. The omission of the notes about the 'exceptional candidates' clause is acceptable as it is considered color or,")))], created=1787404984, model='gpt-4o-2024-08-06', object='chat.completion', service_tier='default', system_fingerprint='fp_17e3c4f467', usage=CompletionUsage(completion_tokens=113, prompt_tokens=433, total_tokens=546, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# extraced companu is::: Soylent Industries
# gold_account is::: Soylent Industries
# Judge response is:: ParsedChatCompletion[~ResponseFormatT](id='chatcmpl-EFfyb7BcimithGvhTGjNGTECfSDYG', choices=[ParsedChoice[~ResponseFormatT](finish_reason='stop', index=0, logprobs=None, message=ParsedChatCompletionMessage[~ResponseFormatT](content='{"accuracy":4,"groundedness":4,"format_score":4,"reasoning":"The candidate\'s extracted answer accurately captures the key details from the original job snippet: the company name, the role, and the years of experience required. The extracted information is fully grounded in the provided text, with no additional or missing information. The format is clear and concise, matching the expected structure for such an extraction task. The golden answer includes a note about the conversion of \'about three years\' to \'3\', which is a minor detail not necessary for the" }', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None, parsed=JudgeVerdict(accuracy=4, groundedness=4, format_score=4, reasoning="The candidate's extracted answer accurately captures the key details from the original job snippet: the company name, the role, and the years of experience required. The extracted information is fully grounded in the provided text, with no additional or missing information. The format is clear and concise, matching the expected structure for such an extraction task. The golden answer includes a note about the conversion of 'about three years' to '3', which is a minor detail not necessary for the")))], created=1787404985, model='gpt-4o-2024-08-06', object='chat.completion', service_tier='default', system_fingerprint='fp_17e3c4f467', usage=CompletionUsage(completion_tokens=114, prompt_tokens=422, total_tokens=536, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# extraced companu is::: Wonka Confectionery Ltd.
# gold_account is::: Wonka Confectionery Ltd
# Judge response is:: ParsedChatCompletion[~ResponseFormatT](id='chatcmpl-EFfydWVLtBNZcf1KnapkaGWDy7M3D', choices=[ParsedChoice[~ResponseFormatT](finish_reason='stop', index=0, logprobs=None, message=ParsedChatCompletionMessage[~ResponseFormatT](content='{"accuracy":4,"groundedness":4,"format_score":4,"reasoning":"The candidate\'s extracted answer accurately captures all the key information from the original job snippet: the company name, the role, and the years of experience required. The extracted answer is fully grounded in the provided text, with no additional or invented content. The format is clear and concise, matching the structure of the golden answer, albeit without the \'notes\' field, which is not essential for the core information extraction. Therefore, the scores for accuracy, groundedness, and" }', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None, parsed=JudgeVerdict(accuracy=4, groundedness=4, format_score=4, reasoning="The candidate's extracted answer accurately captures all the key information from the original job snippet: the company name, the role, and the years of experience required. The extracted answer is fully grounded in the provided text, with no additional or invented content. The format is clear and concise, matching the structure of the golden answer, albeit without the 'notes' field, which is not essential for the core information extraction. Therefore, the scores for accuracy, groundedness, and")))], created=1787404987, model='gpt-4o-2024-08-06', object='chat.completion', service_tier='default', system_fingerprint='fp_17e3c4f467', usage=CompletionUsage(completion_tokens=114, prompt_tokens=422, total_tokens=536, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# extraced companu is::: Stark Industries
# gold_account is::: Stark Industries
# Judge response is:: ParsedChatCompletion[~ResponseFormatT](id='chatcmpl-EFfyfRHYAIAY4Tal2qM8DFOclfVf4', choices=[ParsedChoice[~ResponseFormatT](finish_reason='stop', index=0, logprobs=None, message=ParsedChatCompletionMessage[~ResponseFormatT](content='{"accuracy":4,"groundedness":4,"format_score":4,"reasoning":"The candidate\'s extracted answer is fully accurate and grounded in the original job snippet. The company name, role, and years of experience required are correctly extracted. The format is clear and concise, matching the expected structure for such data extraction tasks. The years of experience are presented as a range, which is consistent with the original snippet, and while the golden answer suggests taking the minimum, the candidate\'s answer is still correct as it reflects the original text."}', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None, parsed=JudgeVerdict(accuracy=4, groundedness=4, format_score=4, reasoning="The candidate's extracted answer is fully accurate and grounded in the original job snippet. The company name, role, and years of experience required are correctly extracted. The format is clear and concise, matching the expected structure for such data extraction tasks. The years of experience are presented as a range, which is consistent with the original snippet, and while the golden answer suggests taking the minimum, the candidate's answer is still correct as it reflects the original text.")))], created=1787404989, model='gpt-4o-2024-08-06', object='chat.completion', service_tier='default', system_fingerprint='fp_17e3c4f467', usage=CompletionUsage(completion_tokens=110, prompt_tokens=434, total_tokens=544, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# extraced companu is::: Cyberdyne Systems
# gold_account is::: Cyberdyne Systems
# Judge response is:: ParsedChatCompletion[~ResponseFormatT](id='chatcmpl-EFfyh0qXEFHbGDLrpEcEz0ulJGUrS', choices=[ParsedChoice[~ResponseFormatT](finish_reason='stop', index=0, logprobs=None, message=ParsedChatCompletionMessage[~ResponseFormatT](content='{"accuracy":4,"groundedness":4,"format_score":4,"reasoning":"The candidate\'s extracted answer is fully accurate and matches the golden answer. It correctly identifies the company and role, and appropriately notes that there is no specific years of experience required, aligning with the original job snippet. The answer is well-grounded as it does not introduce any unsupported information. The format is clear and concise, making it easy to read and understand."}', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None, parsed=JudgeVerdict(accuracy=4, groundedness=4, format_score=4, reasoning="The candidate's extracted answer is fully accurate and matches the golden answer. It correctly identifies the company and role, and appropriately notes that there is no specific years of experience required, aligning with the original job snippet. The answer is well-grounded as it does not introduce any unsupported information. The format is clear and concise, making it easy to read and understand.")))], created=1787404991, model='gpt-4o-2024-08-06', object='chat.completion', service_tier='default', system_fingerprint='fp_17e3c4f467', usage=CompletionUsage(completion_tokens=92, prompt_tokens=437, total_tokens=529, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# extraced companu is::: Acme Corp
# gold_account is::: Acme Corp
# Judge response is:: ParsedChatCompletion[~ResponseFormatT](id='chatcmpl-EFfyi2nvSzL59z3qiN81bVTXJFash', choices=[ParsedChoice[~ResponseFormatT](finish_reason='stop', index=0, logprobs=None, message=ParsedChatCompletionMessage[~ResponseFormatT](content='{"accuracy":4,"groundedness":4,"format_score":4,"reasoning":"The candidate\'s extracted answer accurately captures all the key details from the original job snippet: the company name (Acme Corp), the role (Senior Software Engineer), and the years of experience required (5). These details are directly supported by the text in the job snippet, ensuring full accuracy and groundedness. The format is clear and concise, matching the structure of the golden answer without unnecessary information, thus earning a perfect score in all dimensions."}', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None, parsed=JudgeVerdict(accuracy=4, groundedness=4, format_score=4, reasoning="The candidate's extracted answer accurately captures all the key details from the original job snippet: the company name (Acme Corp), the role (Senior Software Engineer), and the years of experience required (5). These details are directly supported by the text in the job snippet, ensuring full accuracy and groundedness. The format is clear and concise, matching the structure of the golden answer without unnecessary information, thus earning a perfect score in all dimensions.")))], created=1787404992, model='gpt-4o-2024-08-06', object='chat.completion', service_tier='default', system_fingerprint='fp_17e3c4f467', usage=CompletionUsage(completion_tokens=108, prompt_tokens=412, total_tokens=520, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# extraced companu is::: Northwind Ltd.
# gold_account is::: Northwind Ltd
# Judge response is:: ParsedChatCompletion[~ResponseFormatT](id='chatcmpl-EFfykKPAWRj5lQpihc0iPXZwgR4Im', choices=[ParsedChoice[~ResponseFormatT](finish_reason='stop', index=0, logprobs=None, message=ParsedChatCompletionMessage[~ResponseFormatT](content='{"accuracy":4,"groundedness":4,"format_score":4,"reasoning":"The candidate\'s extracted answer accurately captures the key details from the original job snippet, including the company name, role, and years of experience required. The extracted answer is fully grounded in the provided text, with no invented content. The format is clear and concise, matching the structure of the golden answer, albeit without the additional note, which is not essential for the core information extraction."}', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None, parsed=JudgeVerdict(accuracy=4, groundedness=4, format_score=4, reasoning="The candidate's extracted answer accurately captures the key details from the original job snippet, including the company name, role, and years of experience required. The extracted answer is fully grounded in the provided text, with no invented content. The format is clear and concise, matching the structure of the golden answer, albeit without the additional note, which is not essential for the core information extraction.")))], created=1787404994, model='gpt-4o-2024-08-06', object='chat.completion', service_tier='default', system_fingerprint='fp_17e3c4f467', usage=CompletionUsage(completion_tokens=96, prompt_tokens=411, total_tokens=507, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# extraced companu is::: Globex International
# gold_account is::: Globex International
# Judge response is:: ParsedChatCompletion[~ResponseFormatT](id='chatcmpl-EFfymLnf9bTanduqalziVQb3KL4ZX', choices=[ParsedChoice[~ResponseFormatT](finish_reason='stop', index=0, logprobs=None, message=ParsedChatCompletionMessage[~ResponseFormatT](content='{"accuracy":4,"groundedness":4,"format_score":4,"reasoning":"The candidate\'s extracted answer accurately reflects the information provided in the original job snippet. It correctly identifies the company, role, and years of experience required, matching the golden answer. The extracted answer is fully grounded in the provided text, with no additional or invented content. The format is clear and concise, presenting the information in a structured manner that aligns with the expected output."}', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None, parsed=JudgeVerdict(accuracy=4, groundedness=4, format_score=4, reasoning="The candidate's extracted answer accurately reflects the information provided in the original job snippet. It correctly identifies the company, role, and years of experience required, matching the golden answer. The extracted answer is fully grounded in the provided text, with no additional or invented content. The format is clear and concise, presenting the information in a structured manner that aligns with the expected output.")))], created=1787404996, model='gpt-4o-2024-08-06', object='chat.completion', service_tier='default', system_fingerprint='fp_17e3c4f467', usage=CompletionUsage(completion_tokens=94, prompt_tokens=419, total_tokens=513, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# extraced companu is::: Initech
# gold_account is::: Initech
# ...
# extraced companu is::: Globex International
# gold_account is::: Globex International
# Judge response is:: ParsedChatCompletion[~ResponseFormatT](id='chatcmpl-EFfz1ShToPbQXtkcnfjQZZO20Xaxw', choices=[ParsedChoice[~ResponseFormatT](finish_reason='stop', index=0, logprobs=None, message=ParsedChatCompletionMessage[~ResponseFormatT](content='{"accuracy":4,"groundedness":4,"format_score":4,"reasoning":"The candidate\'s extracted answer accurately reflects the information provided in the original job snippet. The company name, role, and years of experience required are correctly identified and match the golden answer. The extracted answer is fully grounded in the provided text, with no additional or invented content. The format is clear, concise, and well-structured, making it easy to read and understand."}', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None, parsed=JudgeVerdict(accuracy=4, groundedness=4, format_score=4, reasoning="The candidate's extracted answer accurately reflects the information provided in the original job snippet. The company name, role, and years of experience required are correctly identified and match the golden answer. The extracted answer is fully grounded in the provided text, with no additional or invented content. The format is clear, concise, and well-structured, making it easy to read and understand.")))], created=1787405011, model='gpt-4o-2024-08-06', object='chat.completion', service_tier='default', system_fingerprint='fp_17e3c4f467', usage=CompletionUsage(completion_tokens=94, prompt_tokens=419, total_tokens=513, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# extraced companu is::: Initech
# gold_account is::: Initech
# Judge response is:: ParsedChatCompletion[~ResponseFormatT](id='chatcmpl-EFfz3BqGgtAgPtzxR0KtztfB6vh1Y', choices=[ParsedChoice[~ResponseFormatT](finish_reason='stop', index=0, logprobs=None, message=ParsedChatCompletionMessage[~ResponseFormatT](content='{"accuracy":4,"groundedness":4,"format_score":4,"reasoning":"The candidate\'s extracted answer accurately captures the key details from the original job snippet: the company (Initech), the role (Lead DevOps Engineer), and the years of experience required (6). These elements are directly supported by the text in the job snippet. The format is clear and concise, matching the expected structure for such an extraction task. There are no inaccuracies or unsupported claims, and the information is presented in a straightforward manner."}', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None, parsed=JudgeVerdict(accuracy=4, groundedness=4, format_score=4, reasoning="The candidate's extracted answer accurately captures the key details from the original job snippet: the company (Initech), the role (Lead DevOps Engineer), and the years of experience required (6). These elements are directly supported by the text in the job snippet. The format is clear and concise, matching the expected structure for such an extraction task. There are no inaccuracies or unsupported claims, and the information is presented in a straightforward manner.")))], created=1787405013, model='gpt-4o-2024-08-06', object='chat.completion', service_tier='default', system_fingerprint='fp_17e3c4f467', usage=CompletionUsage(completion_tokens=107, prompt_tokens=427, total_tokens=534, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# extraced companu is::: Hooli
# gold_account is::: Hooli
# Judge response is:: ParsedChatCompletion[~ResponseFormatT](id='chatcmpl-EFfz5HPJg4YTTz3TflEso85RH2ZSR', choices=[ParsedChoice[~ResponseFormatT](finish_reason='stop', index=0, logprobs=None, message=ParsedChatCompletionMessage[~ResponseFormatT](content='{"accuracy":4,"groundedness":4,"format_score":4,"reasoning":"The candidate\'s extracted answer is fully accurate and grounded in the original job snippet. It correctly identifies the company as \\"Hooli,\\" the role as \\"Junior Frontend Developer,\\" and notes that no prior experience is required, which aligns with the \\"0 years\\" experience requirement. The format is clear and concise, matching the expected structure for such an extraction task."}', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None, parsed=JudgeVerdict(accuracy=4, groundedness=4, format_score=4, reasoning='The candidate\'s extracted answer is fully accurate and grounded in the original job snippet. It correctly identifies the company as "Hooli," the role as "Junior Frontend Developer," and notes that no prior experience is required, which aligns with the "0 years" experience requirement. The format is clear and concise, matching the expected structure for such an extraction task.')))], created=1787405015, model='gpt-4o-2024-08-06', object='chat.completion', service_tier='default', system_fingerprint='fp_17e3c4f467', usage=CompletionUsage(completion_tokens=92, prompt_tokens=416, total_tokens=508, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# extraced companu is::: Pied Piper Inc.
# gold_account is::: Pied Piper Inc.
# Judge response is:: ParsedChatCompletion[~ResponseFormatT](id='chatcmpl-EFfz6mpxGm8fYkTf4P0bAayMUIwgo', choices=[ParsedChoice[~ResponseFormatT](finish_reason='stop', index=0, logprobs=None, message=ParsedChatCompletionMessage[~ResponseFormatT](content='{"accuracy":4,"groundedness":4,"format_score":4,"reasoning":"The candidate\'s extracted answer accurately captures the key details from the original job snippet: the company name, the role, and the years of experience required. The extracted answer is fully grounded in the provided text, as it directly reflects the information given in the job snippet. The format is clear and concise, matching the expected structure for such an extraction task. The candidate\'s answer omits the additional note about exceptional candidates, but this is consistent with the \'f" \n\n}', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None, parsed=JudgeVerdict(accuracy=4, groundedness=4, format_score=4, reasoning="The candidate's extracted answer accurately captures the key details from the original job snippet: the company name, the role, and the years of experience required. The extracted answer is fully grounded in the provided text, as it directly reflects the information given in the job snippet. The format is clear and concise, matching the expected structure for such an extraction task. The candidate's answer omits the additional note about exceptional candidates, but this is consistent with the 'f")))], created=1787405016, model='gpt-4o-2024-08-06', object='chat.completion', service_tier='default', system_fingerprint='fp_17e3c4f467', usage=CompletionUsage(completion_tokens=113, prompt_tokens=433, total_tokens=546, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# extraced companu is::: Soylent Industries
# gold_account is::: Soylent Industries
# Judge response is:: ParsedChatCompletion[~ResponseFormatT](id='chatcmpl-EFfz8QDzlVYzXo0TtWhNG2oQhuj5d', choices=[ParsedChoice[~ResponseFormatT](finish_reason='stop', index=0, logprobs=None, message=ParsedChatCompletionMessage[~ResponseFormatT](content='{"accuracy":4,"groundedness":4,"format_score":4,"reasoning":"The candidate\'s extracted answer accurately captures the key details from the original job snippet: the company name, the role, and the years of experience required. The golden answer includes an additional note about the conversion of \'about three years\' to the numeral 3, but this does not affect the accuracy of the candidate\'s extraction. The extracted answer is fully grounded in the provided text, and the format is clear and concise, matching the expected structure."}', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None, parsed=JudgeVerdict(accuracy=4, groundedness=4, format_score=4, reasoning="The candidate's extracted answer accurately captures the key details from the original job snippet: the company name, the role, and the years of experience required. The golden answer includes an additional note about the conversion of 'about three years' to the numeral 3, but this does not affect the accuracy of the candidate's extraction. The extracted answer is fully grounded in the provided text, and the format is clear and concise, matching the expected structure.")))], created=1787405018, model='gpt-4o-2024-08-06', object='chat.completion', service_tier='default', system_fingerprint='fp_17e3c4f467', usage=CompletionUsage(completion_tokens=109, prompt_tokens=422, total_tokens=531, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# extraced companu is::: Wonka Confectionery Ltd.
# gold_account is::: Wonka Confectionery Ltd
# Judge response is:: ParsedChatCompletion[~ResponseFormatT](id='chatcmpl-EFfzAfg944SIYobBYDoVDfZK3170V', choices=[ParsedChoice[~ResponseFormatT](finish_reason='stop', index=0, logprobs=None, message=ParsedChatCompletionMessage[~ResponseFormatT](content='{"accuracy":4,"groundedness":4,"format_score":4,"reasoning":"The candidate\'s extracted answer is fully accurate and matches the golden answer. All the key details from the original job snippet are correctly captured: the company name, role, and years of experience required. The extracted answer is also well-grounded, as it directly reflects the information provided in the job snippet. The format is clear and concise, with no unnecessary information or errors, making it easy to read and understand."}', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None, parsed=JudgeVerdict(accuracy=4, groundedness=4, format_score=4, reasoning="The candidate's extracted answer is fully accurate and matches the golden answer. All the key details from the original job snippet are correctly captured: the company name, role, and years of experience required. The extracted answer is also well-grounded, as it directly reflects the information provided in the job snippet. The format is clear and concise, with no unnecessary information or errors, making it easy to read and understand.")))], created=1787405020, model='gpt-4o-2024-08-06', object='chat.completion', service_tier='default', system_fingerprint='fp_17e3c4f467', usage=CompletionUsage(completion_tokens=102, prompt_tokens=422, total_tokens=524, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# extraced companu is::: Stark Industries
# gold_account is::: Stark Industries
# Judge response is:: ParsedChatCompletion[~ResponseFormatT](id='chatcmpl-EFfzBqrGKSikth82hi2ZigU3xyXJT', choices=[ParsedChoice[~ResponseFormatT](finish_reason='stop', index=0, logprobs=None, message=ParsedChatCompletionMessage[~ResponseFormatT](content='{"accuracy":4,"groundedness":4,"format_score":4,"reasoning":"The candidate\'s extracted answer is fully accurate and grounded in the original job snippet. It correctly identifies the company, role, and the minimum years of experience required, which aligns with the golden answer. The format is clear and concise, matching the expected structure for such an extraction task."}', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None, parsed=JudgeVerdict(accuracy=4, groundedness=4, format_score=4, reasoning="The candidate's extracted answer is fully accurate and grounded in the original job snippet. It correctly identifies the company, role, and the minimum years of experience required, which aligns with the golden answer. The format is clear and concise, matching the expected structure for such an extraction task.")))], created=1787405021, model='gpt-4o-2024-08-06', object='chat.completion', service_tier='default', system_fingerprint='fp_17e3c4f467', usage=CompletionUsage(completion_tokens=76, prompt_tokens=432, total_tokens=508, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# extraced companu is::: Cyberdyne Systems
# gold_account is::: Cyberdyne Systems
# Judge response is:: ParsedChatCompletion[~ResponseFormatT](id='chatcmpl-EFfzDzlAUQSFzSt2GvqV8kVSKGfib', choices=[ParsedChoice[~ResponseFormatT](finish_reason='stop', index=0, logprobs=None, message=ParsedChatCompletionMessage[~ResponseFormatT](content='{"accuracy":4,"groundedness":4,"format_score":4,"reasoning":"The candidate\'s extracted answer is fully accurate and matches the golden answer. It correctly identifies the company and role, and appropriately notes that there is no specific years of experience required, aligning with the original job snippet. The answer is well-grounded as it does not introduce any unsupported information. The format is clear and concise, making it easy to read and understand."}', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None, parsed=JudgeVerdict(accuracy=4, groundedness=4, format_score=4, reasoning="The candidate's extracted answer is fully accurate and matches the golden answer. It correctly identifies the company and role, and appropriately notes that there is no specific years of experience required, aligning with the original job snippet. The answer is well-grounded as it does not introduce any unsupported information. The format is clear and concise, making it easy to read and understand.")))], created=1787405023, model='gpt-4o-2024-08-06', object='chat.completion', service_tier='default', system_fingerprint='fp_17e3c4f467', usage=CompletionUsage(completion_tokens=92, prompt_tokens=437, total_tokens=529, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# Total scored records: 40
# Results written to: ../data/judge_response1.txt

# %% [markdown]
# ## Step 5 — Build the comparison table

# %%
df = pd.DataFrame(scored)
print("Rows:", len(df))
print("Columns:", df.columns.tolist())

summary = df.groupby('strategy').agg({
    'accuracy': 'mean',
    'parse_success': 'mean',
    'llm_judge_score': 'mean',
    'cost_usd': 'sum',
    'latency_s': 'median',
}).round(3)

summary.columns = ['Accuracy (mean of 3)', 'Parse rate', 'Judge score', 'Total cost ($)', 'Latency p50 (s)']
summary
# Out:
# Rows: 40
# Columns: ['id', 'strategy', 'accuracy', 'parse_success', 'llm_judge_score', 'groundedness', 'format_score', 'judge_reasoning', 'cost_usd', 'latency_s']
#             Accuracy (mean of 3)  Parse rate  Judge score  Total cost ($)  \
# strategy
# cot                          2.8         1.0          4.0           0.001
# few_shot                     2.7         1.0          3.9           0.000
# structured                   2.7         1.0          3.9           0.001
# zero_shot                    2.6         1.0          4.0           0.000
#
#             Latency p50 (s)
# strategy
# cot                   1.177
# few_shot              0.984
# structured            1.141
# zero_shot             1.191

# %% [markdown]
# ## Step 6 — Write your reflection
#
# Open `mp1_writeup.md` and answer the four questions from the brief.
#
# Then commit:
#
# ```bash
# git add mp1/
# git commit -m 'feat(mp1): prompt strategy comparison + writeup'
# ```
